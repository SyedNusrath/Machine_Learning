# %% [markdown]
# ### 1. Read data
# Read the data from CSV and apply some basic pre-processing (remove non-ascii characters, convert our target variable to an integer label).

# %%
import numpy as np
import pandas as pd
from nltk import word_tokenize
from imblearn.under_sampling import RandomUnderSampler

# Keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Flatten, LSTM, Conv1D, MaxPooling1D, Dropout, Activation
from keras.layers.embeddings import Embedding
# Out:
# C:\Users\syed.nusrath\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
path = r"C:\Users\syed.nusrath\Downloads\DATA\Edvancer\project 3 Quora spam identifier\train.csv"

# %%
df = pd.read_csv(path)

# %%
df.shape
# Out:
# (1306122, 3)

# %%
df.head()
# Out:
#                     qid                                      question_text  \
# 0  00002165364db923c7e6  How did Quebec nationalists see their province...
# 1  000032939017120e6e44  Do you have an adopted dog, how would you enco...
# 2  0000412ca6e4628ce2cf  Why does velocity affect time? Does velocity a...
# 3  000042bf85aa498cd78e  How did Otto von Guericke used the Magdeburg h...
# 4  0000455dfa3e01eae3af  Can I convert montra helicon D to a mountain b...
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
docs = df["question_text"].values
labels = df["target"].values

# %%
np.unique(labels,return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([1225312,   80810], dtype=int64))

# %% [markdown]
# ### 2. Preprocessing
# Tokenize text, convert words / tokens to indexed integers. Take each document and convert to a sequence of max length 20 (pad with zeroes if shorter).

# %%
# prepare tokenizer
t = Tokenizer()
t.fit_on_texts(docs)
vocab_size = len(t.word_index) + 1
# integer encode the documents
encoded_docs = t.texts_to_sequences(docs)
print(vocab_size)
# Out:
# 222162

# %%
t.word_index
# Out:
# {'the': 1,
#  'what': 2,
#  'is': 3,
#  'a': 4,
#  'to': 5,
#  'in': 6,
#  'of': 7,
#  'i': 8,
#  'how': 9,
#  'and': 10,
#  'do': 11,
#  'are': 12,
#  'for': 13,
#  'you': 14,
#  'can': 15,
#  'why': 16,
#  'it': 17,
#  'my': 18,
#  'that': 19,
#  'if': 20,
#  'with': 21,
#  'on': 22,
#  'or': 23,
#  'have': 24,
#  'be': 25,
#  'does': 26,
#  'from': 27,
#  'your': 28,
#  'an': 29,
#  'which': 30,
#  'should': 31,
#  'when': 32,
#  'get': 33,
#  'best': 34,
#  'would': 35,
#  'as': 36,
#  'people': 37,
#  'some': 38,
#  'there': 39,
#  'who': 40,
#  'will': 41,
#  'like': 42,
#  'at': 43,
#  'not': 44,
#  'about': 45,
#  'by': 46,
#  'they': 47,
#  'did': 48,
#  'was': 49,
#  'any': 50,
#  'we': 51,
#  'so': 52,
#  'good': 53,
#  'me': 54,
#  'their': 55,
#  'one': 56,
#  'india': 57,
#  'has': 58,
#  'after': 59,
#  'most': 60,
#  'where': 61,
#  'make': 62,
#  'this': 63,
#  'but': 64,
#  'more': 65,
#  'all': 66,
#  'think': 67,
#  'many': 68,
#  'between': 69,
#  'time': 70,
#  'than': 71,
#  'much': 72,
#  'other': 73,
#  'life': 74,
#  'someone': 75,
#  'use': 76,
#  'he': 77,
#  'out': 78,
#  'way': 79,
#  'am': 80,
#  'know': 81,
#  'up': 82,
#  'being': 83,
#  'work': 84,
#  'want': 85,
#  'take': 86,
#  'them': 87,
#  'were': 88,
#  'ever': 89,
#  'his': 90,
#  'find': 91,
#  'us': 92,
#  'become': 93,
#  'world': 94,
#  'without': 95,
#  'just': 96,
#  'could': 97,
#  'feel': 98,
#  'person': 99,
#  "don't": 100,
#  'into': 101,
#  'better': 102,
#  'year': 103,
#  'quora': 104,
#  'no': 105,
#  'go': 106,
#  '2': 107,
#  'new': 108,
#  'possible': 109,
#  'job': 110,
#  'only': 111,
#  'her': 112,
#  'years': 113,
#  'been': 114,
#  'indian': 115,
#  'mean': 116,
#  "what's": 117,
#  "i'm": 118,
#  'used': 119,
#  'need': 120,
#  'start': 121,
#  'first': 122,
#  'trump': 123,
#  'women': 124,
#  'had': 125,
#  'difference': 126,
#  '1': 127,
#  'money': 128,
#  'still': 129,
#  'different': 130,
#  'school': 131,
#  'while': 132,
#  'really': 133,
#  'long': 134,
#  'old': 135,
#  'over': 136,
#  'country': 137,
#  'our': 138,
#  'learn': 139,
#  'now': 140,
#  'business': 141,
#  'same': 142,
#  'love': 143,
#  'before': 144,
#  'college': 145,
#  'things': 146,
#  'even': 147,
#  'engineering': 148,
#  'give': 149,
#  'help': 150,
#  'during': 151,
#  'online': 152,
#  'day': 153,
#  'she': 154,
#  'its': 155,
#  'say': 156,
#  '3': 157,
#  'see': 158,
#  'bad': 159,
#  'because': 160,
#  'using': 161,
#  'book': 162,
#  'university': 163,
#  'back': 164,
#  'men': 165,
#  'change': 166,
#  'company': 167,
#  'then': 168,
#  'high': 169,
#  'sex': 170,
#  'him': 171,
#  'made': 172,
#  'stop': 173,
#  'anyone': 174,
#  'having': 175,
#  'getting': 176,
#  'right': 177,
#  '2017': 178,
#  'girl': 179,
#  'live': 180,
#  'student': 181,
#  'buy': 182,
#  'two': 183,
#  'study': 184,
#  '5': 185,
#  'own': 186,
#  'thing': 187,
#  'happen': 188,
#  'science': 189,
#  'name': 190,
#  'going': 191,
#  'countries': 192,
#  'white': 193,
#  'something': 194,
#  'through': 195,
#  'free': 196,
#  'real': 197,
#  'english': 198,
#  'look': 199,
#  'black': 200,
#  'true': 201,
#  'american': 202,
#  'china': 203,
#  'experience': 204,
#  'such': 205,
#  "can't": 206,
#  'come': 207,
#  'questions': 208,
#  'doing': 209,
#  '2018': 210,
#  '10': 211,
#  'system': 212,
#  'water': 213,
#  'number': 214,
#  'class': 215,
#  'important': 216,
#  'students': 217,
#  'against': 218,
#  'very': 219,
#  'language': 220,
#  'government': 221,
#  'ways': 222,
#  'books': 223,
#  'state': 224,
#  'off': 225,
#  'tell': 226,
#  'man': 227,
#  'computer': 228,
#  'war': 229,
#  'keep': 230,
#  '4': 231,
#  'never': 232,
#  'social': 233,
#  'always': 234,
#  'human': 235,
#  'girls': 236,
#  'every': 237,
#  'friend': 238,
#  'too': 239,
#  'home': 240,
#  'career': 241,
#  'non': 242,
#  'data': 243,
#  'relationship': 244,
#  'chinese': 245,
#  'place': 246,
#  'under': 247,
#  "doesn't": 248,
#  'software': 249,
#  'write': 250,
#  'friends': 251,
#  'future': 252,
#  'x': 253,
#  'done': 254,
#  'working': 255,
#  'exam': 256,
#  'learning': 257,
#  'account': 258,
#  'phone': 259,
#  'website': 260,
#  'app': 261,
#  'america': 262,
#  "it's": 263,
#  'food': 264,
#  'family': 265,
#  'parents': 266,
#  'top': 267,
#  'another': 268,
#  'guy': 269,
#  'got': 270,
#  's': 271,
#  'age': 272,
#  'around': 273,
#  'car': 274,
#  'believe': 275,
#  'days': 276,
#  'states': 277,
#  'read': 278,
#  'happens': 279,
#  'course': 280,
#  'usa': 281,
#  'wrong': 282,
#  'kind': 283,
#  'big': 284,
#  'google': 285,
#  'each': 286,
#  'companies': 287,
#  'power': 288,
#  'down': 289,
#  'hard': 290,
#  'b': 291,
#  'able': 292,
#  'body': 293,
#  'show': 294,
#  'major': 295,
#  'makes': 296,
#  'americans': 297,
#  'also': 298,
#  'movie': 299,
#  'history': 300,
#  'last': 301,
#  'well': 302,
#  'hate': 303,
#  'question': 304,
#  'ask': 305,
#  'canada': 306,
#  'cost': 307,
#  'muslims': 308,
#  'less': 309,
#  'both': 310,
#  'living': 311,
#  'jee': 312,
#  'president': 313,
#  'considered': 314,
#  'type': 315,
#  'pay': 316,
#  'degree': 317,
#  'normal': 318,
#  'create': 319,
#  'test': 320,
#  'woman': 321,
#  'god': 322,
#  'since': 323,
#  'part': 324,
#  'facebook': 325,
#  'instead': 326,
#  'end': 327,
#  'media': 328,
#  'examples': 329,
#  'child': 330,
#  'play': 331,
#  'u': 332,
#  'great': 333,
#  'common': 334,
#  'prepare': 335,
#  'rank': 336,
#  'answer': 337,
#  'children': 338,
#  'process': 339,
#  'market': 340,
#  'actually': 341,
#  'law': 342,
#  'anything': 343,
#  'united': 344,
#  'given': 345,
#  'house': 346,
#  'eat': 347,
#  'marks': 348,
#  'win': 349,
#  'myself': 350,
#  'choose': 351,
#  'tv': 352,
#  'medical': 353,
#  'music': 354,
#  'next': 355,
#  'earth': 356,
#  'average': 357,
#  'known': 358,
#  'making': 359,
#  'call': 360,
#  'jobs': 361,
#  'today': 362,
#  'game': 363,
#  'writing': 364,
#  'cause': 365,
#  'order': 366,
#  'current': 367,
#  'score': 368,
#  'small': 369,
#  'indians': 370,
#  'north': 371,
#  'video': 372,
#  'join': 373,
#  'affect': 374,
#  'service': 375,
#  'apply': 376,
#  'e': 377,
#  'deal': 378,
#  '6': 379,
#  'math': 380,
#  'reason': 381,
#  'main': 382,
#  'self': 383,
#  'causes': 384,
#  'support': 385,
#  'worth': 386,
#  'left': 387,
#  'uk': 388,
#  'bank': 389,
#  'these': 390,
#  'called': 391,
#  'form': 392,
#  'c': 393,
#  'south': 394,
#  'tips': 395,
#  'point': 396,
#  'based': 397,
#  'technology': 398,
#  'face': 399,
#  'put': 400,
#  'word': 401,
#  'public': 402,
#  'energy': 403,
#  'open': 404,
#  'engineer': 405,
#  'delhi': 406,
#  'muslim': 407,
#  'months': 408,
#  'card': 409,
#  'travel': 410,
#  'etc': 411,
#  'pakistan': 412,
#  'management': 413,
#  'value': 414,
#  'iit': 415,
#  'marketing': 416,
#  'those': 417,
#  'others': 418,
#  'move': 419,
#  'research': 420,
#  'taking': 421,
#  'level': 422,
#  'light': 423,
#  'full': 424,
#  'hair': 425,
#  'improve': 426,
#  'development': 427,
#  'design': 428,
#  'lot': 429,
#  'control': 430,
#  'meaning': 431,
#  'date': 432,
#  'problem': 433,
#  'times': 434,
#  '12': 435,
#  'found': 436,
#  'idea': 437,
#  'away': 438,
#  'education': 439,
#  'term': 440,
#  'safe': 441,
#  'single': 442,
#  'program': 443,
#  'health': 444,
#  'care': 445,
#  'city': 446,
#  'physics': 447,
#  'air': 448,
#  'series': 449,
#  'general': 450,
#  'space': 451,
#  'international': 452,
#  'low': 453,
#  'weight': 454,
#  'political': 455,
#  'required': 456,
#  'enough': 457,
#  'donald': 458,
#  'stay': 459,
#  'android': 460,
#  'understand': 461,
#  'field': 462,
#  'talk': 463,
#  'mba': 464,
#  'increase': 465,
#  'movies': 466,
#  'month': 467,
#  'popular': 468,
#  "isn't": 469,
#  'problems': 470,
#  'programming': 471,
#  'favorite': 472,
#  'youtube': 473,
#  'build': 474,
#  '7': 475,
#  'behind': 476,
#  'group': 477,
#  'legal': 478,
#  'humans': 479,
#  'salary': 480,
#  'happened': 481,
#  'available': 482,
#  'everyone': 483,
#  'post': 484,
#  'death': 485,
#  'mobile': 486,
#  'often': 487,
#  'said': 488,
#  'military': 489,
#  'again': 490,
#  'mind': 491,
#  'short': 492,
#  'benefits': 493,
#  'story': 494,
#  'boyfriend': 495,
#  'female': 496,
#  'civil': 497,
#  'dog': 498,
#  'run': 499,
#  'society': 500,
#  'looking': 501,
#  "didn't": 502,
#  'girlfriend': 503,
#  'kill': 504,
#  'culture': 505,
#  'wear': 506,
#  'leave': 507,
#  'successful': 508,
#  'visa': 509,
#  'purpose': 510,
#  'russia': 511,
#  'europe': 512,
#  '0': 513,
#  'due': 514,
#  'religion': 515,
#  'ex': 516,
#  'mass': 517,
#  'per': 518,
#  'side': 519,
#  'role': 520,
#  'web': 521,
#  'party': 522,
#  'related': 523,
#  'germany': 524,
#  'watch': 525,
#  'kids': 526,
#  'information': 527,
#  'admission': 528,
#  'male': 529,
#  'answers': 530,
#  '8': 531,
#  'past': 532,
#  'die': 533,
#  'consider': 534,
#  'speed': 535,
#  'skills': 536,
#  'british': 537,
#  'try': 538,
#  'similar': 539,
#  'tech': 540,
#  'internet': 541,
#  'starting': 542,
#  'force': 543,
#  'colleges': 544,
#  'mechanical': 545,
#  '100': 546,
#  'training': 547,
#  'industry': 548,
#  'product': 549,
#  'guys': 550,
#  'studying': 551,
#  'everything': 552,
#  'few': 553,
#  'else': 554,
#  'pain': 555,
#  'gay': 556,
#  'seen': 557,
#  'modern': 558,
#  'sell': 559,
#  'lose': 560,
#  'opinion': 561,
#  'yourself': 562,
#  'types': 563,
#  'advice': 564,
#  'share': 565,
#  'site': 566,
#  'cat': 567,
#  'fight': 568,
#  'earn': 569,
#  'games': 570,
#  'tax': 571,
#  'effective': 572,
#  'exist': 573,
#  'second': 574,
#  'services': 575,
#  'though': 576,
#  'allowed': 577,
#  '20': 578,
#  'blood': 579,
#  'interview': 580,
#  'rate': 581,
#  'application': 582,
#  'let': 583,
#  'personal': 584,
#  'night': 585,
#  'machine': 586,
#  'themselves': 587,
#  'project': 588,
#  'korea': 589,
#  'police': 590,
#  'area': 591,
#  'rather': 592,
#  'paper': 593,
#  'code': 594,
#  'australia': 595,
#  'foreign': 596,
#  'famous': 597,
#  'marriage': 598,
#  'courses': 599,
#  'bangalore': 600,
#  'set': 601,
#  'case': 602,
#  'private': 603,
#  'terms': 604,
#  'period': 605,
#  'difficult': 606,
#  'already': 607,
#  'effect': 608,
#  'trying': 609,
#  'easy': 610,
#  'mumbai': 611,
#  "i've": 612,
#  'm': 613,
#  'brain': 614,
#  'explain': 615,
#  'compared': 616,
#  'amount': 617,
#  'act': 618,
#  'liberals': 619,
#  'daily': 620,
#  'price': 621,
#  'worst': 622,
#  'skin': 623,
#  'plan': 624,
#  'middle': 625,
#  'says': 626,
#  'treat': 627,
#  'wants': 628,
#  'words': 629,
#  'neet': 630,
#  'hours': 631,
#  'japanese': 632,
#  'team': 633,
#  'towards': 634,
#  'song': 635,
#  'married': 636,
#  'useful': 637,
#  'mother': 638,
#  'universe': 639,
#  'places': 640,
#  'quality': 641,
#  'function': 642,
#  'biggest': 643,
#  'follow': 644,
#  'news': 645,
#  'products': 646,
#  'prevent': 647,
#  'example': 648,
#  'asked': 649,
#  'knowledge': 650,
#  'sleep': 651,
#  'correct': 652,
#  'seem': 653,
#  'once': 654,
#  '15': 655,
#  'yet': 656,
#  'visit': 657,
#  'turn': 658,
#  'amazon': 659,
#  'happy': 660,
#  'cse': 661,
#  'ideas': 662,
#  'rid': 663,
#  'young': 664,
#  'national': 665,
#  'theory': 666,
#  'institute': 667,
#  'taken': 668,
#  'started': 669,
#  'three': 670,
#  'iphone': 671,
#  'coaching': 672,
#  'model': 673,
#  'describe': 674,
#  'wife': 675,
#  'vs': 676,
#  'offer': 677,
#  'lost': 678,
#  'star': 679,
#  'i’m': 680,
#  '9': 681,
#  'list': 682,
#  'effects': 683,
#  'invest': 684,
#  'view': 685,
#  '12th': 686,
#  'oil': 687,
#  'animals': 688,
#  'may': 689,
#  'download': 690,
#  'islam': 691,
#  'gun': 692,
#  'red': 693,
#  'stock': 694,
#  'differences': 695,
#  'far': 696,
#  'avoid': 697,
#  'okay': 698,
#  'line': 699,
#  'week': 700,
#  'instagram': 701,
#  'matter': 702,
#  'negative': 703,
#  'fast': 704,
#  '11': 705,
#  'israel': 706,
#  'character': 707,
#  'thinking': 708,
#  "you've": 709,
#  'eating': 710,
#  'expect': 711,
#  'little': 712,
#  'natural': 713,
#  'security': 714,
#  'com': 715,
#  'sound': 716,
#  'develop': 717,
#  'japan': 718,
#  'chemical': 719,
#  'chance': 720,
#  'provide': 721,
#  'necessary': 722,
#  'jews': 723,
#  'board': 724,
#  'reasons': 725,
#  'exams': 726,
#  'must': 727,
#  'anti': 728,
#  'grow': 729,
#  'likely': 730,
#  'sexual': 731,
#  'size': 732,
#  'present': 733,
#  'professional': 734,
#  'depression': 735,
#  'remove': 736,
#  'modi': 737,
#  'add': 738,
#  'laptop': 739,
#  'chances': 740,
#  'facts': 741,
#  'reading': 742,
#  'feeling': 743,
#  'large': 744,
#  'accept': 745,
#  'within': 746,
#  'army': 747,
#  'schools': 748,
#  'send': 749,
#  'cut': 750,
#  'apps': 751,
#  'dream': 752,
#  'told': 753,
#  'option': 754,
#  'speak': 755,
#  'together': 756,
#  'prefer': 757,
#  'n': 758,
#  'office': 759,
#  'moving': 760,
#  'european': 761,
#  'poor': 762,
#  'preparation': 763,
#  'interested': 764,
#  'becoming': 765,
#  'investment': 766,
#  'fall': 767,
#  'least': 768,
#  'graduate': 769,
#  'phd': 770,
#  'head': 771,
#  'financial': 772,
#  'digital': 773,
#  'don’t': 774,
#  'close': 775,
#  'break': 776,
#  'father': 777,
#  'boy': 778,
#  'fake': 779,
#  'interesting': 780,
#  'paid': 781,
#  'income': 782,
#  'nothing': 783,
#  'mental': 784,
#  'western': 785,
#  '30': 786,
#  'thoughts': 787,
#  'dating': 788,
#  'options': 789,
#  'illegal': 790,
#  'impact': 791,
#  'percentage': 792,
#  'outside': 793,
#  'nuclear': 794,
#  'contact': 795,
#  'here': 796,
#  'drive': 797,
#  'basic': 798,
#  'subject': 799,
#  '50': 800,
#  'french': 801,
#  'upsc': 802,
#  'universities': 803,
#  'husband': 804,
#  'gain': 805,
#  'allow': 806,
#  'comes': 807,
#  'store': 808,
#  'higher': 809,
#  'uses': 810,
#  'studies': 811,
#  'languages': 812,
#  'population': 813,
#  'land': 814,
#  'java': 815,
#  "aren't": 816,
#  'style': 817,
#  'physical': 818,
#  "you're": 819,
#  'interest': 820,
#  'might': 821,
#  '18': 822,
#  'hand': 823,
#  'born': 824,
#  'rights': 825,
#  'special': 826,
#  'chemistry': 827,
#  'gate': 828,
#  'mains': 829,
#  'advantages': 830,
#  'solution': 831,
#  'characteristics': 832,
#  '000': 833,
#  'check': 834,
#  'personality': 835,
#  'websites': 836,
#  'german': 837,
#  'changed': 838,
#  'issues': 839,
#  'email': 840,
#  'intelligence': 841,
#  'racist': 842,
#  'fact': 843,
#  'gets': 844,
#  'teacher': 845,
#  'developer': 846,
#  'baby': 847,
#  'heart': 848,
#  'rich': 849,
#  'please': 850,
#  'created': 851,
#  'recommend': 852,
#  'meet': 853,
#  'branch': 854,
#  'strong': 855,
#  'pressure': 856,
#  'fat': 857,
#  'room': 858,
#  'credit': 859,
#  'russian': 860,
#  'west': 861,
#  'pregnant': 862,
#  'sites': 863,
#  'ms': 864,
#  'marry': 865,
#  'hindi': 866,
#  'economy': 867,
#  'currently': 868,
#  'dark': 869,
#  'startup': 870,
#  'positive': 871,
#  'doctor': 872,
#  'charge': 873,
#  'structure': 874,
#  'laws': 875,
#  'pass': 876,
#  'source': 877,
#  'pursue': 878,
#  'near': 879,
#  'inside': 880,
#  'practice': 881,
#  'solve': 882,
#  'early': 883,
#  'hyderabad': 884,
#  'obama': 885,
#  'spend': 886,
#  'scope': 887,
#  'talking': 888,
#  'building': 889,
#  'smart': 890,
#  'son': 891,
#  'bring': 892,
#  'apple': 893,
#  'whole': 894,
#  'bitcoin': 895,
#  'ok': 896,
#  'views': 897,
#  'africa': 898,
#  'network': 899,
#  'crush': 900,
#  'completely': 901,
#  'christians': 902,
#  'numbers': 903,
#  'windows': 904,
#  'videos': 905,
#  'maths': 906,
#  'art': 907,
#  'partner': 908,
#  'topics': 909,
#  'ca': 910,
#  'd': 911,
#  'alone': 912,
#  'certain': 913,
#  'ones': 914,
#  'officer': 915,
#  'among': 916,
#  'healthy': 917,
#  'especially': 918,
#  'pune': 919,
#  'global': 920,
#  'film': 921,
#  'cell': 922,
#  'content': 923,
#  'cbse': 924,
#  'gas': 925,
#  'works': 926,
#  'iq': 927,
#  'factors': 928,
#  'text': 929,
#  'according': 930,
#  'exactly': 931,
#  'complete': 932,
#  'written': 933,
#  'needed': 934,
#  'christian': 935,
#  'fear': 936,
#  'dogs': 937,
#  'distance': 938,
#  'save': 939,
#  'stupid': 940,
#  'asian': 941,
#  'religious': 942,
#  'reduce': 943,
#  'yes': 944,
#  'songs': 945,
#  'cold': 946,
#  'mom': 947,
#  'ago': 948,
#  'treatment': 949,
#  'east': 950,
#  'electrical': 951,
#  'file': 952,
#  'coming': 953,
#  'playing': 954,
#  'hurt': 955,
#  'insurance': 956,
#  'cs': 957,
#  'giving': 958,
#  'eyes': 959,
#  'race': 960,
#  'attack': 961,
#  'buying': 962,
#  'teach': 963,
#  'minimum': 964,
#  'color': 965,
#  'advanced': 966,
#  'novel': 967,
#  'train': 968,
#  'simple': 969,
#  'letter': 970,
#  'policy': 971,
#  'community': 972,
#  'african': 973,
#  'opportunities': 974,
#  'what’s': 975,
#  'fix': 976,
#  'dead': 977,
#  'democrats': 978,
#  'multiple': 979,
#  'thought': 980,
#  'running': 981,
#  'react': 982,
#  'mathematics': 983,
#  'sense': 984,
#  'result': 985,
#  'abroad': 986,
#  'method': 987,
#  'procedure': 988,
#  'almost': 989,
#  'easily': 990,
#  'lead': 991,
#  'eye': 992,
#  'anxiety': 993,
#  'front': 994,
#  'transfer': 995,
#  'hindu': 996,
#  'clear': 997,
#  'football': 998,
#  'lower': 999,
#  'green': 1000,
#  ...}

# %%
encoded_docs
# Out:
# [[9, 48, 6683, 7219, 158, 55, 6107, 36, 4, 1206, 6, 1, 8333],
#  [11, 14, 24, 29, 3864, 498, 9, 35, 14, 3672, 37, 5, 3089, 10, 44, 1846],
#  [16, 26, 2002, 374, 70, 26, 2002, 374, 451, 5546],
#  [9, 48, 13005, 8284, 52192, 119, 1, 39877, 28269],
#  [15, 8, 1130, 42987, 99430, 911, 5, 4, 3133, 1533, 46, 96, 1465, 1, 9340],
#  [3, 9110, 3898, 765, 19163, 52193, 23, 99431, 13, 2649],
#  [16,
#   26,
#   104,
#   2559,
#   1642,
#   1455,
#   2440,
#   32,
#   4295,
#   64,
#   26,
#   44,
#   11,
#   1,
#   142,
#   13,
#   1165,
#   897],
#  [3, 17, 1960, 20, 8, 2955, 23, 5829, 18, 12856, 225, 12373, 12, 3684],
#  [3,
#   39,
#   205,
#   4,
#   187,
#   36,
#   6552,
#   19572,
#   10,
#   20,
#   52,
#   9,
#   3,
#   19,
#   130,
#   71,
#   6552,
#   25461],
#  [3,
#   17,
#   96,
#   54,
#   23,
#   24,
#   14,
#   89,
#   114,
#   6,
#   63,
#   2182,
#   15421,
#   14,
#   1375,
#   3148,
#   5,
#   1,
#   37,
#   14,
#   654,
#   1712,
#   901,
#   18808,
#   55,
#   1088,
#   1045,
#   52,
#   14,
#   33,
#   5,
#   24,
#   194,
#   106,
#   28,
#   79,
#   10,
#   98,
#   6911,
#   43,
#   6580,
#   9,
#   48,
#   146,
#   166],
#  [2, 15, 14, 156, 45, 2751],
#  [9, 88, 1, 12740, 8163, 3187],
#  [2, 3, 1, 7040, 656, 2606, 201, 2638, 13, 123, 83, 2922],
#  [15,
#   51,
#   76,
#   138,
#   2551,
#   290,
#   4909,
#   36,
#   4,
#   2659,
#   36,
#   302,
#   36,
#   13,
#   243,
#   2652,
#   41,
#   1,
#   243,
#   25,
#   1636],
#  [8,
#   80,
#   786,
#   311,
#   43,
#   240,
#   10,
#   24,
#   105,
#   495,
#   8,
#   35,
#   143,
#   4,
#   495,
#   10,
#   18,
#   186,
#   240,
#   9,
#   15,
#   8,
#   3086,
#   18,
#   1008],
#  [2, 11, 14, 81, 45, 31916, 23360, 10, 1, 99432, 3629],
#  [9, 606, 3, 17, 5, 91, 4, 53, 8773, 5, 86, 4, 215, 879, 14],
#  [24, 14, 12489, 1, 623, 7, 4, 14052],
#  [11,
#   14,
#   67,
#   659,
#   41,
#   3089,
#   29,
#   6,
#   346,
#   1227,
#   5,
#   1643,
#   539,
#   5,
#   1,
#   2538,
#   23,
#   451,
#   253,
#   141,
#   2211],
#  [9, 68, 72254, 821, 573, 746, 4, 4164, 59848],
#  [9, 8, 81, 1146, 4, 179, 125, 254, 170, 144, 170, 21, 54],
#  [9, 11, 8, 93, 4, 704, 9171, 310, 6, 18, 734, 241, 10, 6, 18, 584, 74],
#  [58, 1, 344, 277, 93, 1, 1599, 6108, 6, 1, 94],
#  [2,
#   3,
#   1,
#   4276,
#   5704,
#   14,
#   81,
#   7,
#   24,
#   4773,
#   23,
#   24,
#   4800,
#   6,
#   1,
#   591,
#   7,
#   1540,
#   19,
#   58,
#   105,
#   2638,
#   6,
#   604,
#   7,
#   558,
#   447],
#  [31, 8, 507, 18, 251, 10, 91, 108, 914],
#  [15, 14, 62, 659, 6875, 5406, 1055, 6, 1, 3509],
#  [16, 1492, 183, 13427, 232, 89, 1211, 13, 4, 424, 28270, 229, 2, 3488, 87],
#  [9, 15, 8, 267, 924, 6, 379, 408],
#  [2, 31, 8, 81, 144, 1884, 35202, 10, 209, 1, 52194, 4288],
#  [9, 11, 558, 489, 9505, 943, 3033, 5, 1382, 9846],
#  [30, 2373, 12, 65, 25462, 5, 55, 266, 869, 623, 2373, 23, 423, 623, 2373],
#  [9, 15, 8, 736, 200, 4318, 30, 12, 66, 136, 18, 2038],
#  [20, 29329, 12, 851, 46, 1405, 72255, 26, 286, 19573, 24, 1549, 2308, 4332],
#  [3,
#   174,
#   129,
#   161,
#   2800,
#   798,
#   3,
#   17,
#   386,
#   257,
#   6,
#   210,
#   35,
#   39,
#   25,
#   734,
#   361,
#   13,
#   2800,
#   798,
#   4057,
#   6,
#   210,
#   2081,
#   578],
#  [2, 3, 33399, 9783, 66, 45],
#  [3,
#   39,
#   50,
#   997,
#   2086,
#   69,
#   1,
#   214,
#   7,
#   7177,
#   99433,
#   10,
#   1,
#   6709,
#   12142,
#   10,
#   1486,
#   6,
#   27190,
#   23,
#   17030,
#   20334,
#   13,
#   14516,
#   2144,
#   6,
#   1534],
#  [16, 18, 1626, 129, 3, 3665, 323, 689, 5642, 178, 10, 8, 100, 24, 5391],
#  [2, 26, 333, 17838, 116],
#  [6, 28, 204, 255, 21, 22699, 2, 11, 14, 1111, 22699, 48, 102],
#  [9, 11, 8, 33, 873, 46, 795],
#  [11, 66, 402, 131, 1441, 2559, 33, 2489, 2052, 47, 305, 13, 17],
#  [2, 3, 1, 520, 7, 398, 6, 161, 4, 3475],
#  [31, 8, 2261, 16762, 163, 33400, 13, 545, 148],
#  [61, 15, 8, 690, 1493, 401, 13, 904, 107, 513, 6, 9341],
#  [2, 11, 8, 120, 5, 81, 45, 962, 4, 274, 6, 394, 898, 36, 29, 202],
#  [36,
#   75,
#   40,
#   502,
#   1057,
#   1238,
#   1831,
#   10,
#   1,
#   366,
#   7,
#   1,
#   6912,
#   299,
#   15,
#   8,
#   43,
#   768,
#   1057,
#   1,
#   162,
#   7,
#   17],
#  [2, 3, 1, 364, 817, 7, 1, 162, 9, 5, 6467, 2592, 11911, 46, 14053, 28271],
#  [18,
#   638,
#   14054,
#   54,
#   5,
#   6498,
#   66,
#   112,
#   23979,
#   10,
#   8774,
#   9,
#   15,
#   8,
#   62,
#   112,
#   65,
#   1473,
#   45,
#   87,
#   36,
#   8,
#   41,
#   25,
#   191,
#   5,
#   145,
#   6,
#   56,
#   103],
#  [2,
#   3,
#   19,
#   299,
#   6,
#   30,
#   4,
#   1524,
#   3,
#   10711,
#   101,
#   708,
#   19,
#   12373,
#   41,
#   504,
#   171,
#   10,
#   52,
#   77,
#   1045,
#   6,
#   4,
#   4289,
#   13,
#   60,
#   7,
#   90,
#   74,
#   64,
#   168,
#   5185,
#   5,
#   410,
#   1,
#   94,
#   6,
#   4,
#   6526,
#   23980,
#   196,
#   4289],
#  [16,
#   60,
#   7,
#   1,
#   228,
#   189,
#   181,
#   182,
#   1093,
#   103,
#   588,
#   27,
#   793,
#   592,
#   209,
#   17,
#   46,
#   186,
#   3,
#   138,
#   439,
#   212,
#   133,
#   19,
#   700],
#  [2, 12, 38, 222, 5, 13575, 28, 605, 10, 2, 12, 1, 1713, 7, 209, 17],
#  [16, 11, 51, 99434, 8942, 103],
#  [9, 68, 276, 41, 17, 86, 5, 33, 663, 7, 21648, 20335],
#  [30,
#   586,
#   257,
#   1197,
#   15,
#   25,
#   119,
#   5,
#   4983,
#   23361,
#   5031,
#   965,
#   732,
#   59849,
#   10,
#   12857,
#   7,
#   4,
#   401,
#   2950,
#   42988,
#   952,
#   10,
#   15,
#   17,
#   25,
#   3598,
#   21,
#   4,
#   521,
#   582],
#  [26, 17, 84, 21, 236, 1, 79, 39878, 41, 4030, 2525, 44, 5, 2228, 239, 72],
#  [16, 57, 618, 19929, 49, 52, 826],
#  [12, 39, 50, 1141, 19, 14, 100, 42],
#  [9, 11, 1656, 10, 9068, 1102, 10, 5758],
#  [75,
#   4228,
#   101,
#   28,
#   346,
#   14,
#   2448,
#   10,
#   504,
#   87,
#   47,
#   88,
#   2928,
#   21,
#   111,
#   4,
#   4076,
#   2,
#   279,
#   140],
#  [9, 15, 8, 250, 4, 1357, 45, 42989, 35203],
#  [12, 12741, 102, 10, 1231, 43, 2511, 10, 23981, 527, 71, 5463],
#  [24, 14, 89, 114, 4390, 43, 4, 246, 219, 696, 27, 28, 240],
#  [16, 11, 621, 3705, 836, 84, 302, 6, 772, 575],
#  [26, 11490, 188, 43, 3899, 600],
#  [16, 55, 12, 52, 68, 159, 2798, 7, 8200, 107, 22, 16763],
#  [3, 10109, 30558, 1131],
#  [2, 12, 1, 2565, 6, 2662, 708],
#  [2,
#   12,
#   1,
#   643,
#   470,
#   208,
#   8775,
#   19,
#   14,
#   207,
#   1345,
#   32,
#   609,
#   5,
#   351,
#   1,
#   2460,
#   965,
#   13,
#   4,
#   858],
#  [9, 15, 8, 33, 1180, 3620, 6, 9971],
#  [2, 3, 3599, 108, 12374],
#  [9, 11, 8, 749, 744, 1265, 1733, 195, 29, 840],
#  [16,
#   248,
#   3833,
#   806,
#   1,
#   2615,
#   7,
#   2586,
#   5993,
#   848,
#   14055,
#   147,
#   576,
#   47,
#   24,
#   5686,
#   2142,
#   13,
#   2586,
#   489,
#   14055],
#  [2, 12, 1, 832, 19, 1890, 99435, 11708],
#  [9, 11, 8, 84, 6, 10626, 3212],
#  [11, 521, 846, 2270, 5, 59850, 1046, 881],
#  [16, 58, 1, 541, 93, 4, 433, 16, 11, 51, 5742, 22, 17, 13, 552],
#  [15, 51, 33, 14357, 22, 2076, 19930, 46, 1755],
#  [61, 3, 13886, 140],
#  [2,
#   12,
#   1,
#   575,
#   19,
#   15,
#   25,
#   2324,
#   46,
#   4,
#   264,
#   1617,
#   3476,
#   10,
#   2,
#   12,
#   55,
#   3763,
#   1486],
#  [3,
#   17,
#   896,
#   5,
#   25,
#   3280,
#   28,
#   894,
#   74,
#   10,
#   3957,
#   105,
#   56,
#   2406,
#   3,
#   39,
#   205,
#   187,
#   36,
#   83,
#   5994],
#  [9,
#   11,
#   8,
#   166,
#   1,
#   2225,
#   7,
#   4,
#   367,
#   473,
#   258,
#   1,
#   1184,
#   2225,
#   49,
#   583,
#   106,
#   10,
#   8,
#   11,
#   44,
#   24,
#   1099,
#   5,
#   166,
#   343],
#  [12, 1, 16513, 1173, 3808, 397, 22, 2832],
#  [2, 3, 1, 34, 79, 5, 4826, 4, 179, 95, 2534, 112],
#  [2, 15, 1804, 1304, 33, 14, 6, 1233, 288],
#  [2, 12, 1, 2383, 6499, 363, 3231, 13, 4, 2357, 1404, 2325],
#  [3, 39, 205, 4, 187, 36, 59851, 39879],
#  [2, 12, 38, 34, 145, 13, 2087, 12031, 613, 271],
#  [2, 192, 6, 1, 94, 24, 1368, 7, 1241, 22, 8521, 21, 1, 92],
#  [2, 991, 5, 1, 693, 4508, 6, 8389],
#  [2, 3, 1, 34, 3076, 43, 453, 307, 6, 66, 10164, 7, 146],
#  [11, 14, 1157, 4, 141, 19, 58, 4, 325, 1039, 36, 155, 260],
#  [31,
#   51,
#   426,
#   138,
#   2779,
#   2215,
#   46,
#   230,
#   4428,
#   290,
#   3450,
#   3,
#   19,
#   1,
#   60,
#   572,
#   79],
#  [8,
#   506,
#   29,
#   8522,
#   3262,
#   10,
#   4,
#   429,
#   7,
#   236,
#   100,
#   42,
#   17,
#   9172,
#   19574,
#   6727,
#   56,
#   10,
#   4801,
#   13576,
#   16514,
#   3,
#   39,
#   126,
#   69,
#   54,
#   10,
#   9172,
#   2022,
#   16028,
#   2470,
#   6,
#   18,
#   389,
#   258],
#  [41,
#   1389,
#   25,
#   20336,
#   10,
#   149,
#   4,
#   814,
#   5,
#   6337,
#   160,
#   7,
#   596,
#   2308,
#   42,
#   281,
#   6,
#   1,
#   252],
#  [1061, 9173, 4013, 127, 32, 1061, 822, 185, 8030],
#  [40, 16029, 1, 635, 6, 18, 771],
#  [15, 35204, 1447, 1673, 2271],
#  [9, 15, 14, 882, 63, 72256, 1880, 4, 1087, 291, 1087, 513],
#  [2, 12, 1, 8573, 7, 14056, 6, 1620, 29330],
#  [9, 68, 370, 12, 6, 4827, 595],
#  [2, 11, 6943, 7074, 228, 1871, 10, 6944, 67, 7, 2498, 99436, 99437, 37319],
#  [16, 12, 135, 8659, 27, 2152, 2521, 1249, 678, 6, 1, 367, 505],
#  [15, 8, 81, 18, 8, 3414, 147, 20, 8, 303, 903],
#  [9, 15, 8, 133, 62, 82, 18, 491, 10, 33, 663, 7, 18, 159, 2186, 42, 7250],
#  [49, 39, 50, 244, 69, 7425, 10, 4277, 33401, 7, 99438],
#  [61, 12, 99439, 7605, 436],
#  [2,
#   222,
#   41,
#   4,
#   1080,
#   638,
#   4573,
#   112,
#   330,
#   13,
#   191,
#   105,
#   795,
#   20,
#   330,
#   1302,
#   164,
#   5,
#   795,
#   21,
#   112],
#  [15, 8, 121, 5977, 59, 6311, 33402, 460, 798, 16764],
#  [2, 3, 1, 381, 16, 51, 133, 120, 895],
#  [2, 12, 38, 53, 945, 13, 4, 134, 3451],
#  [20,
#   2187,
#   385,
#   131,
#   1044,
#   10,
#   3138,
#   20744,
#   13,
#   3291,
#   16,
#   100,
#   47,
#   1290,
#   2127],
#  [2, 31, 25, 2053, 5, 13577, 1, 3958, 214, 531, 681, 5, 33, 231, 475],
#  [6, 4, 1351, 1603, 13887, 2, 3, 3149, 1, 392, 7, 1, 574, 1603],
#  [2, 12, 1435, 694, 6847],
#  [8,
#   80,
#   556,
#   778,
#   10,
#   8,
#   143,
#   18,
#   3418,
#   778,
#   77,
#   3,
#   4213,
#   64,
#   8,
#   1692,
#   81,
#   2,
#   5,
#   11,
#   77,
#   3,
#   1137,
#   10,
#   8,
#   85,
#   5,
#   158,
#   90,
#   7426,
#   2,
#   31,
#   8,
#   11],
#  [30, 3415, 24, 1, 3438, 1266],
#  [2, 11, 1, 604, 228, 1725, 42990, 10, 8818, 601, 1725, 17289, 116],
#  [12,
#   671,
#   1316,
#   7322,
#   6061,
#   6,
#   1094,
#   7651,
#   10,
#   6527,
#   5,
#   2956,
#   45,
#   219,
#   2730,
#   2470,
#   1202,
#   205,
#   36,
#   1285,
#   74,
#   1242,
#   19,
#   671,
#   9174,
#   132,
#   73,
#   17839,
#   6,
#   178,
#   210,
#   12,
#   209,
#   209,
#   72,
#   102],
#  [9, 134, 3, 56, 2158, 6, 5200],
#  [16, 11, 2336, 91, 8390, 1644],
#  [2, 12, 1, 34, 222, 5, 738, 6428, 5, 4, 3566, 13888],
#  [2, 564, 11, 14, 24, 13, 174, 40, 5407, 5, 5319, 2, 14, 24],
#  [9, 11, 1063, 18, 2384, 936, 7, 5269, 10, 4887],
#  [2, 12, 38, 329, 7, 8523, 84, 7776],
#  [107,
#   1010,
#   419,
#   379,
#   3090,
#   634,
#   286,
#   73,
#   10,
#   168,
#   419,
#   531,
#   3090,
#   6,
#   99440,
#   2106,
#   2,
#   3,
#   1,
#   938,
#   69,
#   87],
#  [2, 751, 11, 14, 76, 1, 60, 13, 84, 6, 4, 345, 153],
#  [15,
#   1061,
#   111,
#   86,
#   4,
#   1295,
#   546,
#   28272,
#   6,
#   4,
#   8391,
#   8,
#   2923,
#   17,
#   41,
#   111,
#   2625,
#   1,
#   122,
#   546,
#   3,
#   39,
#   2960,
#   5,
#   166,
#   19],
#  [9, 11, 8, 865, 29, 202, 321, 13, 4, 1000, 409, 9, 72, 11, 47, 873],
#  [2,
#   11,
#   287,
#   199,
#   13,
#   32,
#   7251,
#   8875,
#   26,
#   1,
#   6015,
#   7,
#   1,
#   1675,
#   331,
#   4,
#   1571,
#   520],
#  [15, 59852, 2145, 13428, 27191, 25, 119, 5, 465, 3503, 1242],
#  [64,
#   16,
#   48,
#   2124,
#   2676,
#   196,
#   90,
#   3095,
#   59,
#   2,
#   125,
#   481,
#   6,
#   1,
#   6581,
#   229,
#   8,
#   67,
#   77,
#   31,
#   24],
#  [58, 1, 70, 207, 13, 57, 5, 3089, 56, 330, 971],
#  [15, 4, 92, 5073, 3055, 4, 92, 1333, 1537, 101, 1, 5073],
#  [2, 31, 8, 506, 5, 4, 14517, 522],
#  [16, 31, 51, 320, 29, 403, 4509, 18439],
#  [2, 3, 1, 34, 19575, 13, 1, 240, 759, 676, 1, 1261, 759],
#  [61, 15, 8, 91, 2503, 4828, 361],
#  [16, 11, 14871, 2476, 627, 55, 1283, 52, 2833],
#  [2, 3, 1, 988, 5, 684, 6, 1835, 1416],
#  [2, 3, 99441],
#  [2, 3, 1, 60, 18440, 13284, 9011, 7, 1000],
#  [3,
#   17,
#   1754,
#   5,
#   11,
#   613,
#   715,
#   178,
#   1575,
#   6,
#   7178,
#   163,
#   10,
#   121,
#   1376,
#   13,
#   567,
#   210],
#  [2, 3, 1, 126, 69, 4, 3173, 10, 4, 27192],
#  [16, 26, 203, 44, 4643, 4, 3923, 166, 6, 371, 589],
#  [16,
#   11,
#   1693,
#   156,
#   1379,
#   1,
#   2153,
#   960,
#   32,
#   6,
#   843,
#   17,
#   1326,
#   87,
#   136,
#   107,
#   833,
#   113,
#   1143,
#   2634,
#   5547,
#   1397,
#   5,
#   9342,
#   3599,
#   1599,
#   867],
#  [16, 26, 1, 25463, 1598, 82, 880, 18, 4789],
#  [20, 118, 1630, 29, 261, 161, 979, 471, 812, 15, 8, 76, 1, 142, 10044],
#  [2, 12, 1, 53, 10, 159, 2477, 7, 59853, 394, 589],
#  [9, 49, 28, 35205, 35206, 43, 99442, 8031],
#  [58, 75, 21649, 11812, 5, 10549, 45, 14],
#  [9, 15, 8, 121, 18441, 4, 29331, 29332, 4450],
#  [469, 17, 4667, 19, 111, 165, 58, 489, 2866, 6, 394, 589],
#  [9, 48, 31917, 39880, 27, 99443, 2444, 1176, 59854],
#  [9, 1131, 3, 394, 898, 13, 4, 2156],
#  [24, 14, 89, 358, 75, 40, 58, 8717, 838],
#  [16, 3, 163, 7, 24685, 44, 4843, 6, 20745, 3234],
#  [48,
#   8718,
#   7901,
#   892,
#   4,
#   23982,
#   9847,
#   22,
#   90,
#   6209,
#   5,
#   27193,
#   1,
#   25464,
#   101,
#   7815],
#  [9, 41, 4141, 17290, 13429, 13, 52195, 11303, 25],
#  [2, 12, 1, 2686, 7, 13006],
#  [2, 12, 38, 37, 21, 4, 169, 1506, 841],
#  [16, 11, 11209, 3846, 42991, 166, 52, 72, 616, 5, 11491],
#  [2, 3, 1, 365, 7, 2145, 543, 6, 4790],
#  [9, 12, 1, 5529, 998, 15422, 3018],
#  [40,
#   35,
#   349,
#   99444,
#   4910,
#   82,
#   27,
#   2933,
#   1390,
#   1160,
#   1083,
#   2130,
#   19931,
#   676,
#   19576,
#   14057,
#   4910,
#   82,
#   27,
#   2933,
#   1390,
#   1160,
#   1083,
#   2130,
#   19931],
#  [30, 4342, 259, 31, 25, 34],
#  [3, 17, 18, 3363, 19, 18, 2192, 1129, 58, 159, 233, 993],
#  [18133, 10, 46994, 12, 8032, 362, 3, 23, 12, 30, 3, 2295],
#  [6,
#   2,
#   4533,
#   58,
#   2127,
#   10045,
#   7,
#   99445,
#   59855,
#   114,
#   5247,
#   10,
#   2,
#   222,
#   24,
#   47,
#   341,
#   6135,
#   1,
#   1657,
#   7,
#   277,
#   5,
#   62,
#   55,
#   186,
#   875],
#  [35,
#   1693,
#   1100,
#   5,
#   2897,
#   6,
#   1,
#   2173,
#   229,
#   13,
#   1,
#   4888,
#   7,
#   706,
#   10,
#   1327,
#   66,
#   1,
#   723,
#   20,
#   47,
#   2494,
#   19,
#   322,
#   1449,
#   24686,
#   706,
#   10,
#   77,
#   41,
#   11,
#   5,
#   1693,
#   2,
#   1,
#   2350,
#   85,
#   5,
#   11,
#   5,
#   1,
#   723],
#  [9, 11, 14, 121, 4, 1470, 22, 104],
#  [30, 2483, 3292, 31, 8, 351, 13, 4, 260, 42, 19164],
#  [2, 11, 14, 11, 36, 4, 6161, 3985],
#  [2, 15, 8, 11, 5, 25, 4, 102, 181, 6, 131],
#  [16, 26, 6974, 8524, 5044, 680, 2006, 75],
#  [2, 12, 185, 329, 7, 16270],
#  [16, 12, 7745, 52, 8077],
#  [3,
#   72257,
#   72258,
#   4,
#   441,
#   246,
#   5,
#   657,
#   6,
#   2205,
#   23,
#   39,
#   3,
#   50,
#   936,
#   7,
#   1865,
#   23,
#   194],
#  [9, 15, 8, 3419, 1, 56, 187, 5, 166, 18, 74, 4802],
#  [16, 26, 18, 4040, 6405, 90, 16515],
#  [30, 3, 34, 25465, 13, 671, 475, 6, 57],
#  [20,
#   29,
#   357,
#   3395,
#   633,
#   4791,
#   4,
#   31918,
#   40,
#   97,
#   5830,
#   62,
#   4,
#   462,
#   2114,
#   27,
#   546,
#   11107,
#   35,
#   47,
#   349,
#   1,
#   1160,
#   5017],
#  [15, 8, 504, 350, 140],
#  [9, 15, 56, 569, 27, 1076, 6, 5643, 340],
#  [2, 12, 38, 7, 1, 2222, 1010, 6, 1, 94],
#  [32, 15, 51, 81, 4889, 6975],
#  [2, 31, 8, 139, 59, 2616, 3924, 5, 93, 4, 53, 994, 327, 846],
#  [16, 11, 27194, 13143, 55, 977, 592, 71, 2212, 42, 1, 73, 1115],
#  [3, 39, 4, 3129, 40, 15, 150, 54, 1123, 784, 444, 839],
#  [2, 3, 1, 4601, 637, 74, 13, 4, 4323, 1343, 72259, 21, 4, 6913, 7, 99446],
#  [11,
#   14,
#   67,
#   263,
#   4,
#   1030,
#   7,
#   3086,
#   19,
#   6945,
#   12,
#   8201,
#   537,
#   202,
#   10,
#   2070,
#   7713],
#  [118, 1, 13578, 8819, 4510, 363, 9, 11, 14, 33, 5, 1, 267, 7, 8334, 99447],
#  [9, 11, 8, 319, 4, 5152, 4278, 212],
#  [2, 3, 28, 74, 42, 185, 113, 27, 362],
#  [16, 11, 37, 2216, 23983, 4014, 20, 47, 12, 219, 2309],
#  [9,
#   3,
#   12858,
#   14678,
#   292,
#   5,
#   2082,
#   52,
#   68,
#   11912,
#   1849,
#   218,
#   171,
#   132,
#   5304,
#   3,
#   83,
#   19932,
#   5,
#   1095,
#   1149,
#   22,
#   205,
#   1849],
#  [30, 3, 1, 34, 667, 13, 284, 243, 5140, 280, 6, 3091],
#  [2, 3, 1, 26281, 2092, 22, 4, 228],
#  [2, 3, 1, 34, 246, 5, 182, 906, 447, 1087, 4850],
#  [26,
#   1,
#   37,
#   40,
#   12,
#   849,
#   10,
#   129,
#   1037,
#   2401,
#   24,
#   50,
#   9343,
#   16,
#   12,
#   47,
#   345,
#   2401,
#   20,
#   12,
#   849],
#  [12,
#   39,
#   6312,
#   7,
#   3298,
#   2344,
#   929,
#   83,
#   1029,
#   7714,
#   101,
#   2637,
#   2344,
#   13,
#   1,
#   510,
#   7,
#   3705],
#  [30, 1476, 3, 1, 34, 13, 29, 766, 6, 2687],
#  [310,
#   54,
#   10,
#   18,
#   804,
#   12,
#   175,
#   9569,
#   8,
#   85,
#   5,
#   647,
#   138,
#   330,
#   27,
#   63,
#   44,
#   656,
#   10790,
#   3,
#   17,
#   109],
#  [9, 26, 17, 98, 5, 410, 99448, 6, 4, 2978, 3235, 27, 1, 99449],
#  [30, 162, 3, 53, 13, 288, 1540],
#  [9, 3, 17, 109, 5, 62, 8876, 22, 1734, 21, 732, 7, 99450, 9, 26, 17, 188],
#  [32,
#   191,
#   5,
#   29,
#   580,
#   3,
#   17,
#   4,
#   53,
#   437,
#   5,
#   506,
#   4,
#   200,
#   2756,
#   21,
#   1,
#   2742,
#   23,
#   506,
#   1,
#   1046,
#   193,
#   23,
#   73,
#   423,
#   5627,
#   2756],
#  [26, 237, 17840, 24, 26282, 1147],
#  [2, 12, 1, 1417, 563, 7, 584, 33403, 6, 72260],
#  [16,
#   12,
#   297,
#   537,
#   3647,
#   4774,
#   10,
#   108,
#   12143,
#   314,
#   5,
#   25,
#   1862,
#   1500,
#   147,
#   32,
#   47,
#   66,
#   755,
#   1,
#   142,
#   220],
#  [30, 3, 34, 17841, 13, 3747, 1818, 231],
#  [43, 2, 396, 11, 14, 149, 82, 609, 5, 459, 251, 21, 75],
#  [2, 12, 1, 832, 19, 1890, 1, 2263, 3240, 979, 1099, 72261],
#  [9, 51, 15, 76, 108, 699, 6, 17560, 15, 14, 615, 21, 648],
#  [11, 14, 85, 4, 5873, 20, 52, 2, 13],
#  [20, 310, 3793, 3019, 10, 4245, 10378, 767, 27, 1, 4547, 2855, 40, 41, 1038],
#  [2, 296, 14, 3467, 1, 60, 10, 1, 27195],
#  [11, 14, 24, 5, 1220, 4, 734, 224, 1426, 5, 25, 4, 28273, 11210],
#  [2, 3, 1, 622, 3206, 19, 58, 5687, 22, 5485],
#  [2, 3, 307, 7, 6035, 18809, 17561, 4534],
#  [2,
#   124,
#   98,
#   32,
#   154,
#   4180,
#   1,
#   74,
#   7,
#   227,
#   46,
#   99451,
#   4229,
#   171,
#   13,
#   1305,
#   2436,
#   1822],
#  [40, 1598, 7816, 5644, 6, 9012, 4, 1534, 190],
#  [2, 3, 1, 34, 18810, 3600, 19, 16030, 1242, 10, 1364],
#  [9, 290, 3, 17, 5, 25, 1558, 5, 957, 1995, 43, 42992, 2184, 28274],
#  [21,
#   1,
#   4548,
#   7,
#   1289,
#   2,
#   3,
#   1,
#   431,
#   387,
#   7,
#   1295,
#   2733,
#   621,
#   7,
#   646,
#   36,
#   39,
#   3,
#   56,
#   1206,
#   56,
#   571,
#   140],
#  [16,
#   12,
#   1165,
#   3468,
#   52,
#   42993,
#   634,
#   20746,
#   21,
#   11813,
#   39881,
#   99452,
#   31,
#   2818,
#   123,
#   25,
#   4,
#   1236,
#   5,
#   25,
#   12742,
#   23,
#   99453,
#   3803],
#  [3, 127, 6914, 1556, 457, 5, 319, 1, 22179, 4309],
#  [2, 12, 1, 9281, 2186, 7, 18442],
#  [9, 48, 99454, 93, 4707, 17842, 6, 9711],
#  [30, 3, 102, 5, 76, 39882, 23, 23984],
#  [9, 135, 35, 7285, 12490, 25, 362],
#  [16,
#   248,
#   52196,
#   921,
#   60,
#   7,
#   55,
#   52197,
#   6,
#   1,
#   344,
#   277,
#   10,
#   44,
#   1535,
#   3039,
#   1,
#   52196,
#   10712,
#   12,
#   6,
#   2226],
#  [15, 14, 1085, 4, 108, 2003, 20, 14, 100, 42, 17],
#  [30,
#   3,
#   102,
#   3945,
#   5,
#   373,
#   69,
#   687,
#   10,
#   6915,
#   8,
#   24,
#   114,
#   1515,
#   6,
#   310,
#   1,
#   287,
#   13,
#   1,
#   142,
#   1035,
#   10,
#   142,
#   316,
#   36,
#   3,
#   1,
#   602,
#   6,
#   9013,
#   30,
#   167,
#   31,
#   8,
#   757,
#   10,
#   16],
#  [2,
#   12,
#   38,
#   7,
#   1,
#   20747,
#   2396,
#   140,
#   19,
#   14,
#   158,
#   41,
#   62,
#   4,
#   284,
#   791,
#   6,
#   1,
#   252],
#  [2, 3, 1, 382, 520, 7, 9905, 6, 4, 13007, 1113],
#  [15,
#   51,
#   66,
#   140,
#   2316,
#   19,
#   313,
#   123,
#   248,
#   133,
#   85,
#   1538,
#   5,
#   876,
#   7523,
#   7179,
#   8719,
#   5,
#   1340,
#   12032],
#  [20,
#   14,
#   12,
#   27,
#   4391,
#   854,
#   43,
#   2203,
#   15,
#   14,
#   1658,
#   82,
#   50,
#   1439,
#   23,
#   17,
#   523,
#   1255,
#   36,
#   2419],
#  [9, 26, 260, 42, 99455, 715, 23, 29333, 715, 62, 128],
#  [2,
#   591,
#   38,
#   1051,
#   19,
#   8,
#   120,
#   5,
#   86,
#   6,
#   18,
#   3002,
#   911,
#   6,
#   366,
#   5,
#   25,
#   292,
#   5,
#   2371,
#   4,
#   3347,
#   2007,
#   177,
#   59,
#   17],
#  [15, 14, 507, 4, 1285, 9640, 9443, 6, 136, 585],
#  [9, 11, 14, 98, 45, 1380, 21, 37, 40, 12, 3352],
#  [14058,
#   10,
#   10379,
#   6656,
#   24,
#   14,
#   119,
#   4,
#   6684,
#   42,
#   6136,
#   5,
#   1027,
#   28,
#   8574,
#   7989,
#   10,
#   6137,
#   20,
#   44,
#   168,
#   2,
#   11,
#   14,
#   76],
#  [2,
#   26,
#   17,
#   116,
#   19,
#   18,
#   495,
#   7,
#   157,
#   113,
#   989,
#   234,
#   58,
#   107,
#   23,
#   157,
#   39883,
#   95,
#   1466,
#   29,
#   6269,
#   32,
#   77,
#   3,
#   21,
#   54,
#   263,
#   333,
#   64,
#   3,
#   19,
#   318],
#  [61, 3, 11108, 39884, 10, 2, 12, 1, 640, 5, 657, 39],
#  [2, 279, 32, 14, 12, 4229, 7, 8476],
#  [16, 11, 37, 120, 5, 463, 45, 55, 555],
#  [61, 11, 8, 182, 34, 1856, 3648, 6, 884, 57],
#  [8,
#   24,
#   4,
#   34,
#   238,
#   10,
#   8,
#   85,
#   5,
#   886,
#   38,
#   584,
#   70,
#   21,
#   171,
#   64,
#   77,
#   1748,
#   14200,
#   73,
#   37,
#   5,
#   207,
#   373,
#   92,
#   9,
#   11,
#   8,
#   226,
#   171,
#   8,
#   85,
#   38,
#   99456,
#   70,
#   95,
#   171,
#   708,
#   1277,
#   7,
#   17],
#  [9, 15, 8, 2071, 3625, 822, 15627, 22, 9641, 195, 4, 3357],
#  [2, 12, 1, 832, 7, 99457, 29334, 857, 13285],
#  [11, 28275, 946, 213, 150, 555, 6, 823],
#  [32,
#   41,
#   1,
#   99458,
#   1603,
#   173,
#   83,
#   7387,
#   4229,
#   7,
#   2179,
#   17,
#   502,
#   1905,
#   10,
#   173,
#   83,
#   7682],
#  [3,
#   39,
#   4,
#   70,
#   14,
#   1805,
#   42,
#   1327,
#   562,
#   160,
#   14,
#   2385,
#   2780,
#   29,
#   7041,
#   22180,
#   7,
#   1,
#   142,
#   187,
#   136,
#   10,
#   136],
#  [9, 11, 14, 30559, 15628, 10, 15818, 42994],
#  [30, 145, 4561, 41, 465, 18, 740, 7, 176, 4, 169, 1350, 110],
#  [9, 5, 690, 8776, 635, 21, 2210, 1684],
#  [9, 68, 3787, 84, 6, 108, 1286, 446],
#  [2, 26, 499, 261, 13, 786, 3317, 116],
#  [24687, 4141, 10, 99459, 24, 4, 1121],
#  [15, 937, 341, 2132, 78, 7, 6138],
#  [1,
#   202,
#   867,
#   3,
#   1505,
#   247,
#   5233,
#   3015,
#   16,
#   11,
#   37,
#   129,
#   303,
#   123,
#   36,
#   4,
#   313],
#  [2, 12, 1, 887, 7, 1540, 10, 1135, 854],
#  [36,
#   7,
#   3207,
#   210,
#   2,
#   3,
#   3912,
#   885,
#   367,
#   82,
#   5,
#   9,
#   3,
#   77,
#   2663,
#   90,
#   70,
#   10,
#   403],
#  [32, 3, 7857, 766, 6016, 9642, 5, 684, 4, 4625, 754],
#  [30, 3, 1, 34, 11404, 247, 12375, 3479],
#  [117, 1, 5530, 187, 19, 89, 481, 5, 174],
#  [9, 11, 8, 62, 4, 3673, 2019, 15629, 7902],
#  [3, 72262, 452, 1091, 854, 386, 13, 241, 427],
#  [3,
#   39,
#   4,
#   126,
#   69,
#   1218,
#   905,
#   13,
#   650,
#   676,
#   742,
#   13,
#   650,
#   30,
#   2126,
#   3248,
#   5,
#   1,
#   34,
#   3510],
#  [9, 12, 51, 1601, 5, 33, 390, 550, 78, 7, 3621, 227, 521, 1390],
#  [2, 3, 29, 648, 7, 99460, 115, 9111],
#  [3,
#   39,
#   4,
#   1777,
#   3587,
#   19,
#   3,
#   358,
#   13,
#   4708,
#   1639,
#   744,
#   28276,
#   4668,
#   1,
#   732,
#   7,
#   55,
#   2543],
#  [3, 10791, 6, 524, 610],
#  [3, 1103, 1241, 43, 1, 414, 3649, 6946, 4, 2885, 18134, 7, 11024],
#  [2, 12, 1061, 1061, 8, 8, 1235, 6, 2065, 827],
#  [2, 3, 1, 19165, 99461, 10, 99462, 7, 2969],
#  [2, 5125, 15, 14, 76, 5, 3528, 27, 99463, 5, 99464],
#  [118,
#   1108,
#   5,
#   182,
#   4,
#   1533,
#   4,
#   46995,
#   632,
#   56,
#   30,
#   3,
#   102,
#   99465,
#   19933,
#   72263,
#   1061,
#   1958,
#   23,
#   1,
#   59856,
#   99466],
#  [30, 3, 1, 60, 6582, 5874, 446, 1, 344, 277],
#  [20,
#   403,
#   15,
#   4310,
#   25,
#   851,
#   3706,
#   2878,
#   168,
#   9,
#   26,
#   17,
#   147,
#   573,
#   160,
#   105,
#   56,
#   15,
#   319,
#   17],
#  [2, 3, 1, 988, 5, 33, 528, 6, 5579, 13, 4047],
#  [9, 11, 8, 349, 18, 2060, 136, 18, 2266, 516],
#  [2, 35, 188, 20, 237, 671, 89, 2136, 15819, 43, 1, 142, 70],
#  [9, 11, 8, 42995, 18, 858, 95, 128],
#  [9, 72, 70, 35, 17, 86, 13, 203, 5, 1737, 1, 894, 57],
#  [3, 3299, 239, 1097, 5, 139, 471, 10, 62, 4, 241, 6, 17],
#  [16, 100, 762, 192, 2625, 65, 128, 5, 76, 13, 1350, 13, 439, 411],
#  [40, 11, 14, 42, 65, 18, 719, 4254, 23, 11405, 15630],
#  [1,
#   179,
#   118,
#   888,
#   5,
#   469,
#   501,
#   13,
#   4,
#   2012,
#   244,
#   31,
#   8,
#   305,
#   20,
#   2095,
#   4,
#   2409,
#   6,
#   1,
#   252],
#  [16,
#   11,
#   66,
#   1,
#   37,
#   40,
#   1037,
#   2226,
#   58,
#   333,
#   1594,
#   106,
#   3174,
#   237,
#   70,
#   2095,
#   4,
#   108,
#   4549],
#  [31, 8, 3221, 3709, 18, 2811, 23, 33, 4, 108, 228],
#  [97,
#   1,
#   1605,
#   7,
#   1301,
#   25,
#   977,
#   68,
#   113,
#   948,
#   10,
#   1,
#   1605,
#   7,
#   2061,
#   1301,
#   3,
#   341,
#   4,
#   779,
#   1605],
#  [2, 12, 38, 2151, 27, 59857, 2184, 72264],
#  [30, 471, 220, 31, 8, 139, 5, 404, 4, 249, 167],
#  [3, 3480, 4, 53, 754, 5, 736, 390, 99467, 1773, 273, 18, 2038],
#  [2, 12, 38, 8720, 2200, 264, 1833],
#  [9, 15, 453, 5201, 991, 5, 999, 18135, 6, 4, 2566, 867],
#  [9, 15, 14, 226, 4, 7148, 27, 4, 1080],
#  [24, 14, 89, 499, 29, 152, 1234, 834, 22, 75, 2, 18443, 14, 5, 11, 17],
#  [30, 249, 11, 8, 757, 53, 13, 1289, 35207],
#  [2, 3, 1, 1599, 22181, 19, 15, 25, 436, 6, 2226],
#  [11, 14, 67, 51, 66, 2668, 2347],
#  [16,
#   11,
#   1,
#   619,
#   40,
#   499,
#   748,
#   351,
#   44,
#   5,
#   24,
#   3330,
#   1099,
#   1,
#   526,
#   6,
#   2226,
#   88,
#   1064,
#   514,
#   5,
#   29,
#   13286,
#   2183],
#  [916, 390, 2698, 30, 11, 14, 534, 36, 46996, 19, 50, 14201, 31, 5018],
#  [9, 26, 1, 500, 982, 151, 28, 440, 4228, 43, 2583],
#  [11, 1268, 37, 305, 208],
#  [16, 11, 8, 98, 1655, 1218, 18, 266, 272],
#  [9, 15, 8, 76, 1404, 6, 2535, 6876],
#  [49, 1842, 14872, 4, 9643, 1338],
#  [2, 1756, 5, 1, 1124, 7, 537, 5045, 5, 1037, 1, 4522, 61, 10459, 4774, 2478],
#  [3, 39, 50, 5186, 261, 22, 52198, 1734],
#  [16, 816, 1045, 7, 66, 688, 1257],
#  [9,
#   15,
#   8,
#   1623,
#   76,
#   4,
#   521,
#   1116,
#   6,
#   4,
#   1095,
#   7,
#   342,
#   20,
#   19,
#   1116,
#   248,
#   573,
#   1358],
#  [2, 3, 3331, 11406],
#  [9, 15, 8, 319, 1, 60, 6447, 1676, 5, 278],
#  [16, 48, 412, 876, 1, 5858, 598, 618, 144, 57],
#  [2, 3, 268, 401, 13, 5464],
#  [975, 17, 42, 311, 6, 1, 13889],
#  [3, 39, 4, 53, 935, 30560, 45, 788],
#  [2, 12, 1, 382, 255, 7, 284, 243],
#  [9, 15, 8, 647, 18, 16031, 2207, 27, 39885],
#  [2,
#   26,
#   1,
#   357,
#   8434,
#   7,
#   681,
#   705,
#   10,
#   2593,
#   7,
#   1,
#   3139,
#   67,
#   45,
#   2,
#   133,
#   481,
#   19,
#   153,
#   10627,
#   1054,
#   5508,
#   40,
#   88,
#   39],
#  [32, 48, 1097, 3298, 625, 17031, 879, 59858, 18811, 10, 9784, 347, 55, 5032],
#  [9, 15, 1, 1118, 7, 5332, 25, 6109],
#  [30, 261, 3, 34, 5, 1685, 5, 6243, 354],
#  [3, 138, 4296, 22, 233, 328, 111],
#  [61, 3, 1, 34, 246, 13, 3106, 33404, 6, 42996, 1313],
#  [16, 26, 1, 2032, 550, 6, 18, 167, 1410, 54, 946, 4474],
#  [2, 3, 1, 339, 7, 11709, 1722, 3900],
#  [2, 12, 38, 637, 395, 13, 75, 40, 3, 542, 84, 43, 14202, 1843],
#  [9, 48, 14, 560, 19, 301, 3608, 7, 9906, 857],
#  [30, 148, 854, 31, 25, 351, 5, 376, 13, 3092, 1964, 6, 3364],
#  [2, 1437, 361, 15, 8, 86, 82, 10, 61],
#  [9, 11, 8, 968, 18, 937, 5, 504, 24688],
#  [35,
#   14,
#   3318,
#   28,
#   804,
#   20,
#   14,
#   2217,
#   171,
#   175,
#   170,
#   21,
#   90,
#   472,
#   72265,
#   20,
#   77,
#   1029,
#   626,
#   77,
#   2385,
#   430,
#   1449,
#   36,
#   90,
#   3840,
#   2769,
#   49,
#   765,
#   201],
#  [15, 4562, 12376, 923, 25, 314, 36, 4, 5978, 7, 1, 574, 46997, 7, 4181],
#  [16,
#   3,
#   17,
#   19,
#   4383,
#   4523,
#   30,
#   481,
#   6,
#   138,
#   1487,
#   1607,
#   24,
#   2074,
#   740,
#   7,
#   7858,
#   1,
#   1398,
#   74,
#   4583,
#   36,
#   616,
#   5,
#   1,
#   914,
#   1925,
#   6,
#   138,
#   1607],
#  [2, 3, 4, 53, 648, 7746, 59859, 10304],
#  [16, 26, 74, 1410, 555, 10, 6138],
#  [9, 15, 8, 6183, 5895],
#  [2,
#   12,
#   1,
#   830,
#   10,
#   1329,
#   7,
#   3043,
#   37320,
#   22,
#   37321,
#   918,
#   6,
#   183,
#   20337,
#   6,
#   57],
#  [2, 146, 209, 620, 41, 166, 2312, 99468, 1686, 10, 835],
#  [2, 3, 1, 34, 79, 5, 139, 3332, 2479],
#  [32,
#   364,
#   3236,
#   320,
#   1849,
#   10,
#   7715,
#   9,
#   72,
#   3925,
#   3,
#   239,
#   72,
#   3925,
#   32,
#   35208,
#   1,
#   1051],
#  [2, 12, 38, 369, 656, 216, 6657, 19, 5687, 6, 1689],
#  [3,
#   63,
#   1,
#   34,
#   70,
#   5,
#   182,
#   4,
#   42997,
#   8078,
#   43,
#   127,
#   705,
#   36,
#   7,
#   1,
#   10380,
#   7,
#   14679,
#   99469],
#  [16, 48, 18, 33405, 1746, 7252],
#  [2, 12, 1, 34, 79, 5, 337, 4, 304, 22, 104, 10, 33, 65, 82, 1290],
#  [15, 8, 76, 1959, 27, 73, 3452, 96, 958, 859, 5, 1, 1184, 2796],
#  [1544, 1448, 25, 345, 4, 196, 876, 5, 499, 1, 221, 50, 79, 47, 158, 1453],
#  [48, 1, 537, 4926, 96, 8777, 1413],
#  [9, 15, 8, 376, 13, 59860, 256, 6, 57, 152],
#  [2, 3, 102, 71, 5957],
#  [16032, 830, 7, 439],
#  [3, 39, 4, 79, 5, 121, 4, 11211, 1762, 27, 4, 99470, 95, 175, 5, 76, 99471],
#  [16, 11, 37, 98, 14518, 23, 15061, 132, 1127, 866],
#  [9,
#   31,
#   8,
#   335,
#   13,
#   5486,
#   1575,
#   497,
#   20,
#   8,
#   125,
#   1785,
#   37322,
#   348,
#   6,
#   5486,
#   210,
#   10,
#   8,
#   80,
#   6,
#   18,
#   301,
#   2158,
#   7,
#   145],
#  [99472, 1391, 5433, 49, 2309, 5, 76, 134, 70],
#  [2, 12, 38, 329, 7, 2239, 95, 543],
#  [2, 3, 17562, 2137],
#  [2, 3, 5202, 4318],
#  [16, 3, 1, 2058, 8525, 56, 7, 1, 1599, 1019, 22700, 6, 94, 1854],
#  [3,
#   39,
#   50,
#   321,
#   73,
#   71,
#   407,
#   40,
#   3,
#   660,
#   59,
#   3875,
#   4,
#   407,
#   269,
#   36,
#   39,
#   12,
#   4,
#   429,
#   7,
#   530,
#   22,
#   104,
#   45,
#   143,
#   11212,
#   10,
#   66,
#   7,
#   87,
#   5408,
#   4,
#   429,
#   59,
#   3875,
#   4,
#   407,
#   269],
#  [9, 26, 1, 2271, 1263, 84],
#  [2,
#   279,
#   32,
#   4,
#   228,
#   1170,
#   5,
#   25,
#   15234,
#   13,
#   29,
#   3376,
#   2,
#   1409,
#   11,
#   1,
#   590,
#   76],
#  [12, 39, 68, 597, 52199, 2832, 6, 558, 153, 1738, 362],
#  [30,
#   12,
#   1,
#   34,
#   4683,
#   863,
#   13,
#   1438,
#   3637,
#   6,
#   215,
#   705,
#   8,
#   2414,
#   53,
#   348,
#   6,
#   1530],
#  [30, 162, 3, 34, 6, 537, 300, 13, 1200],
#  [2, 3, 1, 34, 196, 152, 6877, 372, 566, 13, 630, 1918, 10, 1128],
#  [9, 53, 3, 1, 3020, 7, 527, 398, 27, 1, 163, 7, 15820, 595],
#  [9, 26, 1, 1701, 7, 203, 166, 1, 685, 7, 6108],
#  [20, 17, 109, 5, 368, 4, 53, 14873, 2820, 6, 30561, 46, 111, 3056, 7426, 208],
#  [9, 3, 1, 34, 79, 5, 755, 198, 42, 4, 537],
#  [9, 15, 8, 11, 1150, 420, 10, 33, 3025, 43, 272, 655],
#  [30, 12, 1, 34, 640, 5, 522, 6, 600],
#  [3,
#   17,
#   441,
#   5,
#   684,
#   2867,
#   617,
#   7,
#   128,
#   6,
#   152,
#   694,
#   340,
#   1076,
#   6,
#   57,
#   20,
#   44,
#   2,
#   35,
#   25,
#   1,
#   1749,
#   2144],
#  [9, 72, 26, 2138, 2797, 13, 439, 465, 1, 641, 7, 439],
#  [16, 11, 35209, 188],
#  [2, 12, 1, 34, 222, 5, 1058, 28, 8033, 59861, 673, 35210, 786, 12255],
#  [16,
#   11,
#   590,
#   1760,
#   33,
#   5,
#   106,
#   22,
#   781,
#   6728,
#   507,
#   144,
#   176,
#   2957,
#   61,
#   1,
#   357,
#   5248,
#   96,
#   844,
#   2957,
#   40,
#   23985,
#   63,
#   4964],
#  [9, 15, 8, 93, 3763, 6, 19166],
#  [2, 3, 1, 2054, 365, 7, 484, 8164, 1567, 1119, 6, 1, 489],
#  [3, 4, 10046, 19167, 4, 917, 1021],
#  [16, 35, 4, 7493, 747, 10872, 305, 13, 4, 3518, 1591, 409],
#  [30, 315, 7, 9344, 3, 119, 6, 12859],
#  [6, 1118, 2, 3, 8721],
#  [36,
#   29,
#   12860,
#   23,
#   9785,
#   6500,
#   1405,
#   30,
#   79,
#   7,
#   708,
#   3,
#   60,
#   4021,
#   3965,
#   23,
#   242,
#   3965],
#  [9, 72, 454, 15, 8, 3600, 22, 267, 7, 18, 739],
#  [9, 11, 8, 93, 1964, 59, 215, 435],
#  [16,
#   20,
#   4,
#   227,
#   40,
#   58,
#   125,
#   54,
#   136,
#   185,
#   434,
#   40,
#   51,
#   310,
#   81,
#   12,
#   1547,
#   5,
#   10,
#   42,
#   286,
#   73,
#   305,
#   16,
#   8,
#   1142,
#   32,
#   77,
#   2525,
#   54,
#   136,
#   3,
#   77,
#   501,
#   13,
#   7560,
#   32,
#   39,
#   8,
#   459,
#   13,
#   157,
#   231,
#   631,
#   43,
#   4,
#   70],
#  [9, 72, 4, 108, 2287, 7388, 6, 57, 10, 9, 68, 563, 7, 4182, 12, 39],
#  [18,
#   1611,
#   2267,
#   15631,
#   3404,
#   3,
#   44,
#   83,
#   4390,
#   46,
#   50,
#   20338,
#   23,
#   3357,
#   2677,
#   5074,
#   9,
#   15,
#   8,
#   976,
#   63,
#   1089],
#  [2, 35, 24, 4230, 980, 7, 1, 1097, 946, 229, 2280, 2415, 1489],
#  [30, 747, 49, 102, 15423, 23, 1952],
#  [2,
#   31,
#   8,
#   2471,
#   32,
#   8,
#   305,
#   18,
#   238,
#   13,
#   4,
#   712,
#   150,
#   10,
#   77,
#   2386,
#   54,
#   99473,
#   19,
#   8,
#   41,
#   24,
#   5,
#   316,
#   13,
#   90,
#   150],
#  [2, 12, 1, 1051, 5, 93, 29, 2275, 6, 1346, 25, 17, 372, 23, 243],
#  [2, 12, 38, 832, 7, 99474, 10, 37323, 1711],
#  [11, 7253, 24, 170, 21, 55, 5283],
#  [3, 7524, 35211, 4, 53, 299],
#  [2, 3, 17, 42, 5, 84, 36, 29, 1582, 13, 13287],
#  [16, 48, 1, 5705, 156, 19, 308, 12, 4, 5094, 5, 63, 94],
#  [2, 3, 1, 431, 7, 244, 21, 4, 179, 27, 183, 103],
#  [30,
#   464,
#   443,
#   3,
#   1877,
#   13,
#   4,
#   872,
#   6,
#   1,
#   462,
#   7,
#   603,
#   881,
#   13,
#   136,
#   786,
#   113],
#  [16, 502, 1, 5487, 5075, 2169, 47, 1428, 5, 5075, 4343],
#  [9, 72, 128, 11, 8, 120, 5, 182, 4, 925, 2139],
#  [2, 3, 1, 9848, 5153, 987, 13, 7859, 1, 403, 28277, 6, 4, 1612, 10941, 14874],
#  [20, 8778, 248, 805, 517, 6270, 2, 35, 60, 730, 25, 1, 384],
#  [2, 688, 12, 1168, 5, 1968],
#  [15, 1526, 62, 14, 65, 3275],
#  [319, 1, 60, 966, 1036, 89, 27, 868, 311, 23, 4297, 99475],
#  [61, 3, 4, 53, 246, 13, 9972, 70, 25466, 905, 7, 3824, 3710, 6, 20748, 1872],
#  [2, 12, 1, 2571, 7, 2292, 537, 8435],
#  [5187,
#   152,
#   377,
#   1192,
#   1909,
#   42,
#   1792,
#   5249,
#   117,
#   1,
#   34,
#   9069,
#   443,
#   709,
#   1050,
#   45,
#   23,
#   119],
#  [2, 49, 1, 382, 381, 7, 2146, 69, 52200, 10, 99476],
#  [15, 8, 182, 59862, 21, 26283, 59, 4094, 17, 10, 9],
#  [16, 206, 8, 93, 4, 7652],
#  [15, 2119, 25, 4, 53, 13890],
#  [9, 72, 3, 1, 94, 386],
#  [20, 14, 125, 5, 351, 69, 701, 10, 104, 2, 35, 14, 351],
#  [2, 3, 1, 532, 392, 7, 727, 24, 114],
#  [2, 12, 38, 7, 1, 53, 5488, 13, 257, 4965, 2103, 13, 29, 3087, 1933],
#  [9,
#   15,
#   51,
#   370,
#   62,
#   2561,
#   9234,
#   37,
#   461,
#   19,
#   57,
#   851,
#   10,
#   4694,
#   1,
#   16033,
#   13,
#   1,
#   1198,
#   7,
#   2561,
#   4398,
#   1413,
#   10,
#   57,
#   502,
#   24,
#   50,
#   2841,
#   7990],
#  [2, 3, 1, 34, 79, 5, 3385, 4, 429, 7, 2418, 1059],
#  [15, 18, 1559, 158, 18, 2660, 208, 323, 178, 10550, 1140],
#  [9, 26, 2532, 11304, 624, 5, 504, 18812, 6, 16034, 331],
#  [16, 100, 1, 5665, 2173, 484, 1342, 7, 124, 6, 55, 192],
#  [9, 196, 23, 1608, 3, 6, 1, 281, 2, 26, 17, 116, 5, 14, 2596],
#  [2, 12, 1, 558, 13891, 7716, 5776, 46, 2550, 6878],
#  [9, 15, 8, 1278, 4, 379, 103, 135, 5, 347, 917],
#  [2,
#   12,
#   1,
#   1329,
#   7,
#   161,
#   982,
#   1168,
#   13,
#   1704,
#   1168,
#   751,
#   377,
#   1007,
#   326,
#   7,
#   3901],
#  [2, 3, 1, 4550, 10, 12614, 7, 1, 4626, 40, 373, 2264],
#  [9, 11, 8, 93, 4, 2389, 908, 43, 659],
#  [40, 3, 1, 10381, 496, 6, 1, 94],
#  [2, 481, 5, 46998, 3650],
#  [8, 989, 1516, 98, 18136, 16],
#  [9, 15, 8, 91, 4, 221, 110],
#  [2, 3, 1, 126, 69, 4, 2669, 9712, 10, 4, 46999],
#  [61,
#   15,
#   8,
#   690,
#   320,
#   389,
#   13,
#   4829,
#   1,
#   907,
#   189,
#   10,
#   339,
#   13,
#   1124,
#   99477,
#   31919],
#  [9, 68, 217, 1249, 13, 30562, 237, 103],
#  [9, 4611, 6, 57, 1074, 5247, 45, 23986, 9282],
#  [2, 26, 4, 3763, 403, 11814, 11],
#  [2,
#   133,
#   279,
#   6,
#   47000,
#   1061,
#   29335,
#   198,
#   9713,
#   32,
#   37324,
#   1087,
#   23,
#   911,
#   12,
#   28278,
#   46,
#   758,
#   377,
#   1007,
#   12377,
#   10,
#   7286,
#   6,
#   2205,
#   11815,
#   3,
#   17,
#   4,
#   99478,
#   5777,
#   99479,
#   99480,
#   99481,
#   23,
#   96,
#   758,
#   21,
#   1,
#   1087,
#   911,
#   5154,
#   2205,
#   7075,
#   9506],
#  [40, 12, 14, 191, 5, 853, 20, 14, 106, 5, 2874],
#  [16,
#   2306,
#   1178,
#   99482,
#   1,
#   1000,
#   6468,
#   6,
#   1975,
#   22,
#   356,
#   253,
#   6468,
#   99483,
#   7427,
#   5,
#   29336,
#   294,
#   171,
#   421,
#   82,
#   1,
#   17843],
#  [11, 1, 10942, 757, 2868, 5, 1238],
#  [3,
#   17,
#   722,
#   5,
#   9644,
#   28,
#   480,
#   27,
#   1,
#   301,
#   2297,
#   132,
#   12861,
#   6,
#   4,
#   108,
#   167,
#   6,
#   17],
#  [9, 68, 28279, 12, 39, 6, 82, 8660, 178, 256],
#  [16, 3, 13892, 4324, 271, 1, 1384, 13, 13892, 8165],
#  [2, 3, 1, 126, 69, 3881, 4228, 10, 3923, 9570],
#  [117, 38, 7, 1, 643, 162, 4695, 836, 6528],
#  [32,
#   48,
#   99484,
#   6658,
#   505,
#   93,
#   36,
#   5565,
#   36,
#   17,
#   3,
#   140,
#   10,
#   9,
#   15,
#   1,
#   566,
#   4966,
#   63,
#   923,
#   102,
#   95,
#   83,
#   239,
#   15632],
#  [22, 2, 153, 12, 5409, 83, 15821, 78, 13, 3638],
#  [2, 283, 7, 2033, 15, 150, 14, 1744, 4, 1201, 26, 9014, 341, 84],
#  [16,
#   43,
#   434,
#   8,
#   15,
#   2891,
#   99485,
#   10,
#   15,
#   1212,
#   237,
#   442,
#   1818,
#   990,
#   10,
#   168,
#   43,
#   434,
#   8,
#   99486,
#   32,
#   8,
#   755,
#   10,
#   206,
#   147,
#   2891,
#   10,
#   93,
#   78,
#   7,
#   5859],
#  [30, 200, 4758, 15, 1592, 2983, 23, 3, 36, 855, 36, 171],
#  [2, 3, 1, 126, 69, 4, 35212, 10, 29, 23987, 99],
#  [16,
#   11,
#   1076,
#   409,
#   363,
#   99487,
#   3957,
#   42,
#   526,
#   12,
#   55,
#   382,
#   6848,
#   32,
#   1994,
#   7,
#   55,
#   2163,
#   12,
#   1387,
#   578,
#   113,
#   135],
#  [2, 130, 2567, 26, 1, 11213, 3748, 24, 71, 1, 19577],
#  [2,
#   48,
#   14,
#   182,
#   22,
#   4,
#   42998,
#   19,
#   1651,
#   78,
#   5,
#   25,
#   1,
#   5421,
#   766,
#   14,
#   89,
#   172],
#  [15, 8, 1239, 312, 966, 21, 448, 127, 20, 8, 184, 56, 103, 175, 53, 798, 650],
#  [9, 72, 65, 455, 72266, 41, 17, 86, 13, 1448, 5, 658, 22, 123],
#  [2, 3, 1, 60, 19578, 492, 494],
#  [26, 1, 623, 33, 1636, 59, 8661, 1, 425, 623, 22, 2553, 10, 2245],
#  [9, 15, 8, 76, 197, 70, 1809, 22, 18, 1793, 260],
#  [2, 12, 1, 4491, 2096, 5, 25, 2594, 5, 745, 3609, 27, 2910, 3, 4, 5489],
#  [2, 20, 1, 370, 125, 114, 6, 246, 7, 1, 693, 23988, 6, 1, 8079, 94, 449],
#  [16, 12, 1214, 7, 1, 3460, 391, 3420],
#  [16, 11, 52, 68, 2189, 506, 8166],
#  [2, 12, 1, 245, 6406, 8122, 7777],
#  [9, 15, 8, 91, 78, 1, 3222, 46, 111, 161, 1, 4278, 214, 6, 1, 388],
#  [16, 11, 8, 143, 542, 5743, 10, 359, 37, 1616],
#  [31, 8, 76, 18, 614, 65],
#  [9, 26, 1, 13430, 543, 1208, 15424, 2544, 2254, 1257, 5, 1, 14680, 543],
#  [9, 26, 9015, 199, 42],
#  [2, 3, 4, 15822, 546, 2536, 386],
#  [16, 48, 18, 4262, 173, 43, 157, 4602, 6, 1, 1528],
#  [2, 3, 1, 126, 69, 5046, 1813, 10, 843, 1813],
#  [9, 1131, 7, 29, 1036, 3, 4, 72267],
#  [2, 12, 38, 222, 13, 4, 24689, 5, 1488, 27, 4, 3935, 1678, 3804],
#  [9,
#   15,
#   913,
#   1122,
#   22701,
#   360,
#   587,
#   19,
#   32,
#   47,
#   275,
#   4,
#   321,
#   31,
#   533,
#   71,
#   24,
#   29,
#   2499,
#   5,
#   939,
#   112,
#   74],
#  [9,
#   3,
#   1009,
#   4,
#   243,
#   1964,
#   5,
#   6659,
#   1,
#   665,
#   867,
#   130,
#   71,
#   1009,
#   29,
#   8202,
#   5,
#   6659,
#   1,
#   142,
#   867],
#  [9, 15, 8, 33, 16516, 1033, 5548],
#  [816,
#   942,
#   37,
#   1335,
#   19,
#   55,
#   6754,
#   1712,
#   914,
#   12,
#   1218,
#   87,
#   132,
#   1379,
#   161,
#   1,
#   4492,
#   3871,
#   23,
#   175,
#   170],
#  [9, 72, 454, 15, 4, 5351, 6755, 4268, 1220, 6, 15425],
#  [3, 39, 4, 79, 5, 1215, 4, 141, 1270, 7, 28, 141, 22, 325, 9, 11, 14, 11, 17],
#  [30, 2211, 26, 1, 15235, 52201, 47001, 5509, 3794, 21, 9, 11, 47, 1102],
#  [2, 315, 7, 3319, 15, 25, 980, 7, 6, 4, 446, 42, 7494, 2859, 21, 4, 369, 766],
#  [9, 11, 8, 368, 53, 348, 6, 1005, 582, 13, 2426, 99488],
#  [9, 26, 7683, 6879, 13, 728, 2087, 1383, 84],
#  [16, 49, 4, 242, 3411, 1684, 95, 10047, 23, 17291, 2004],
#  [16, 12, 72268, 23362, 11305, 2329, 234, 52, 1354, 616, 5, 60, 73, 7991],
#  [3, 39, 50, 79, 5, 33, 956, 7, 3959, 183, 7747],
#  [2,
#   12,
#   18,
#   740,
#   5,
#   6636,
#   29,
#   1128,
#   1260,
#   247,
#   4131,
#   224,
#   2020,
#   6,
#   861,
#   2587,
#   21,
#   47002,
#   348,
#   6,
#   630,
#   178,
#   6,
#   4,
#   221,
#   145],
#  [2, 12, 38, 1549, 180, 184, 986, 1832, 19, 14, 24],
#  [32,
#   77,
#   58,
#   5,
#   106,
#   3421,
#   23,
#   86,
#   23,
#   11,
#   194,
#   13,
#   90,
#   1112,
#   77,
#   626,
#   8,
#   15,
#   106,
#   64,
#   32,
#   8,
#   11,
#   185,
#   6244,
#   6,
#   1,
#   274,
#   2734,
#   77,
#   2291,
#   4,
#   568,
#   10,
#   15426,
#   54,
#   10,
#   626,
#   1606,
#   6313,
#   90,
#   153,
#   16],
#  [2,
#   26,
#   8613,
#   7,
#   451,
#   70,
#   116,
#   51,
#   81,
#   19,
#   39,
#   469,
#   4,
#   35213,
#   1071,
#   6,
#   451,
#   19,
#   3,
#   8335,
#   52,
#   2,
#   3,
#   17],
#  [16,
#   11,
#   297,
#   757,
#   96,
#   5,
#   44,
#   294,
#   82,
#   3421,
#   592,
#   71,
#   399,
#   147,
#   1,
#   52202,
#   7,
#   5645,
#   18,
#   6210,
#   10,
#   8,
#   24,
#   15823,
#   4,
#   1505,
#   214,
#   7,
#   37,
#   40,
#   4603,
#   50,
#   399,
#   5,
#   399,
#   7561,
#   95,
#   50,
#   2638,
#   43,
#   66],
#  [9, 2309, 3, 4635, 7042],
#  [9,
#   15,
#   8,
#   4436,
#   69,
#   2572,
#   8167,
#   205,
#   36,
#   291,
#   1411,
#   295,
#   10,
#   1007,
#   2419,
#   23,
#   393,
#   295,
#   10,
#   4,
#   2419],
#  [11, 51, 98, 138, 3913],
#  [2, 12, 1, 725, 13, 1373, 10943],
#  [2, 31, 1, 318, 14519, 848, 581, 25, 151, 1444],
#  [9, 15, 4474, 8722, 1340, 14, 6, 202, 998],
#  [18,
#   516,
#   503,
#   10,
#   8,
#   180,
#   6,
#   130,
#   192,
#   51,
#   12,
#   219,
#   72,
#   6,
#   143,
#   10,
#   1011,
#   25,
#   756,
#   13,
#   157,
#   65,
#   113,
#   2,
#   31,
#   51,
#   11],
#  [2, 12, 1, 1996, 69, 1135, 10, 527],
#  [30, 167, 15, 8, 376, 6, 521, 427, 1757, 175, 107, 113, 7, 204, 6, 5646],
#  [2, 279, 20, 8, 1021, 127, 15, 7, 5647, 403],
#  [30, 3, 1, 643, 5270, 6, 1, 198, 5333],
#  [40, 1699, 1, 558, 3324, 666],
#  [15, 51, 1130, 1296, 1541, 101, 99489, 403, 95, 4, 946, 293],
#  [3, 99490, 2781, 5352, 4319, 23, 3026],
#  [9,
#   53,
#   12,
#   18,
#   740,
#   7,
#   176,
#   1558,
#   13,
#   770,
#   43,
#   1723,
#   9507,
#   5126,
#   158,
#   1652,
#   13,
#   1317],
#  [3, 513, 99491, 1257, 5, 513, 59863, 160, 7, 21165],
#  [16, 3, 57, 341, 391, 36, 57],
#  [2, 384, 42999, 37325, 43, 28, 240],
#  [16, 26, 18, 495, 149, 54, 1, 3174, 949],
#  [2, 3, 1, 300, 7, 10713, 6, 228, 189],
#  [9, 11, 14, 173, 359, 2229, 32, 954, 2907],
#  [2, 3, 1, 34, 1343, 5, 84, 36, 4, 3377, 1669],
#  [16, 35, 14, 711, 5, 24, 8575, 2728, 21, 99492, 1589],
#  [2, 3, 47003, 6, 9381, 1096],
#  [26, 14358, 9973, 2580, 6, 10460],
#  [2, 12, 72269, 302, 2654, 233, 5434],
#  [20, 9283, 3, 44, 201, 16, 11, 38, 37, 1355, 55, 532, 1045],
#  [16,
#   1160,
#   9345,
#   10,
#   508,
#   3986,
#   40,
#   12,
#   10461,
#   23,
#   6916,
#   100,
#   85,
#   5,
#   25,
#   991,
#   6,
#   1034],
#  [40, 3, 730, 5, 25, 4866, 6, 198, 4, 33406, 23, 4, 5628],
#  [40, 3, 9974, 1, 60, 1056, 707, 6, 1, 1992, 1474, 7525],
#  [16,
#   12,
#   66,
#   7,
#   1,
#   60,
#   468,
#   1652,
#   22,
#   24690,
#   12,
#   218,
#   1,
#   9175,
#   4269,
#   1,
#   914,
#   22,
#   25467,
#   12,
#   1122,
#   9175,
#   345,
#   24690,
#   10,
#   25467,
#   24,
#   539,
#   455,
#   3716],
#  [2, 26, 1, 1113, 7, 1, 17292, 9112, 8285, 7],
#  [3, 1, 440, 8526, 4737, 29, 1388, 8526, 440],
#  [16,
#   11,
#   52,
#   68,
#   37,
#   1297,
#   218,
#   3242,
#   8165,
#   22182,
#   44,
#   457,
#   5058,
#   1653,
#   39886,
#   243,
#   5,
#   121,
#   21],
#  [2, 3, 28, 561, 22, 1777, 20339],
#  [2, 3, 1, 34, 1113, 13, 14359, 3269, 20340],
#  [24, 14, 89, 668, 28, 3926, 70, 13579, 4, 2027, 162],
#  [2, 3, 1, 887, 6, 716, 148, 6, 57, 10, 2, 3, 1, 3639, 782, 7, 716, 1298],
#  [8,
#   96,
#   678,
#   4,
#   3630,
#   16,
#   206,
#   8,
#   158,
#   18,
#   108,
#   3630,
#   7350,
#   17,
#   58,
#   114,
#   607,
#   231,
#   276],
#  [3, 17, 109, 13, 4, 235, 5, 67, 1231],
#  [41,
#   17,
#   25,
#   2023,
#   20,
#   8,
#   1229,
#   127,
#   103,
#   10,
#   1249,
#   13,
#   17,
#   490,
#   20,
#   18,
#   1216,
#   63,
#   103,
#   12,
#   44,
#   53,
#   457],
#  [619,
#   12,
#   1122,
#   1044,
#   64,
#   1,
#   4196,
#   727,
#   25,
#   3927,
#   46,
#   87,
#   122,
#   3,
#   63,
#   29,
#   1915,
#   3601,
#   7,
#   619],
#  [3, 17, 318, 5, 560, 28, 7817, 5450, 151, 29, 883, 1444],
#  [2, 3, 1, 414, 7, 1880, 10462, 1880, 18137],
#  [2, 11, 1, 3420, 67, 7, 1, 99493],
#  [24,
#   14,
#   89,
#   1153,
#   23,
#   31920,
#   4,
#   321,
#   40,
#   58,
#   457,
#   818,
#   1901,
#   10,
#   3,
#   1948,
#   7322,
#   5,
#   27196,
#   4967,
#   82,
#   10,
#   17032,
#   29,
#   357,
#   227,
#   6,
#   602,
#   7,
#   83,
#   19,
#   722,
#   13,
#   112,
#   2024],
#  [2,
#   249,
#   35,
#   14,
#   24691,
#   6,
#   366,
#   5,
#   91,
#   1,
#   2235,
#   21,
#   1,
#   60,
#   1188,
#   22,
#   4,
#   325,
#   477,
#   23,
#   1039],
#  [16,
#   12,
#   394,
#   115,
#   3711,
#   30,
#   12,
#   3124,
#   46,
#   371,
#   370,
#   65,
#   9714,
#   71,
#   3711,
#   3124,
#   46,
#   394,
#   115,
#   2329],
#  [9,
#   72,
#   2517,
#   26,
#   4,
#   1160,
#   18138,
#   2445,
#   9,
#   68,
#   37,
#   12,
#   4110,
#   10,
#   13,
#   9,
#   134,
#   6,
#   14058,
#   1,
#   1648,
#   168,
#   889,
#   1,
#   7903],
#  [30, 603, 145, 3, 53, 6, 5271],
#  [9, 15, 8, 166, 18, 301, 190, 6, 1060],
#  [2,
#   12,
#   38,
#   1965,
#   10,
#   109,
#   1155,
#   7,
#   586,
#   257,
#   6,
#   74,
#   3069,
#   10165,
#   5531,
#   1450,
#   10,
#   2518,
#   3069],
#  [9, 11, 14, 2580, 4, 200, 3201, 3009],
#  [31,
#   14,
#   25,
#   292,
#   5,
#   190,
#   1022,
#   287,
#   14,
#   24,
#   3966,
#   5,
#   974,
#   20,
#   105,
#   4068,
#   58,
#   9382],
#  [2, 3, 4, 27197, 9, 3, 17, 130, 27, 4, 772, 5979],
#  [9, 15, 51, 474, 383, 2317, 6, 124],
#  [16, 11, 202, 3125, 3481, 245, 398],
#  [2, 8392, 8, 49, 824, 27, 268, 235, 83, 8, 774, 1355, 83, 824],
#  [15,
#   8,
#   33,
#   1128,
#   1260,
#   6,
#   2467,
#   353,
#   72270,
#   6,
#   2859,
#   20,
#   18,
#   224,
#   72271,
#   3,
#   59864],
#  [176,
#   4,
#   833,
#   742,
#   27,
#   193,
#   2554,
#   1868,
#   8123,
#   5,
#   1,
#   1649,
#   2167,
#   2,
#   26,
#   19,
#   116],
#  [9,
#   134,
#   11,
#   14,
#   67,
#   17,
#   41,
#   86,
#   13,
#   104,
#   5,
#   736,
#   63,
#   304,
#   4325,
#   5320,
#   4927,
#   4,
#   4231],
#  [61, 15, 8, 72272, 38, 15062, 6, 3308, 4164],
#  [2, 3, 1, 2367, 13, 7717, 2869, 8723],
#  [3, 27198, 4, 14681],
#  [11,
#   7460,
#   341,
#   445,
#   45,
#   14,
#   42,
#   47,
#   35,
#   4,
#   238,
#   23,
#   11,
#   47,
#   445,
#   365,
#   1560,
#   55,
#   110],
#  [2,
#   26,
#   17,
#   116,
#   20,
#   8,
#   24,
#   4,
#   423,
#   8393,
#   10,
#   1023,
#   18,
#   771,
#   3,
#   6,
#   555,
#   10,
#   17,
#   8,
#   98,
#   19,
#   17,
#   41,
#   2062,
#   101,
#   1001],
#  [15, 8, 33, 661, 854, 6, 1671, 1091, 20, 18, 336, 3, 99494],
#  [3,
#   17,
#   478,
#   13,
#   4,
#   29337,
#   23,
#   1763,
#   55,
#   110,
#   5,
#   697,
#   4,
#   20341,
#   3631,
#   5045,
#   10,
#   129,
#   1037,
#   4003,
#   6,
#   1060],
#  [916, 66, 30, 249, 375, 397, 287, 24, 809, 480],
#  [9, 134, 35, 17, 86, 13, 75, 5, 2094, 20, 14, 1320, 5608],
#  [9, 233, 2951, 863, 84, 21, 561, 2607, 1197, 1415, 22, 1347, 1652],
#  [12, 14, 209, 28, 752, 110],
#  [16, 3, 5958, 1, 643, 3549, 515, 7904, 10, 5959, 1605, 7, 1, 94, 59, 6184],
#  [9, 3, 9715, 13893, 119, 6, 1348, 7, 3217],
#  [99495, 1015],
#  [26,
#   4,
#   1697,
#   7,
#   11816,
#   96,
#   7562,
#   23,
#   26,
#   286,
#   1405,
#   3400,
#   106,
#   225,
#   42,
#   11306],
#  [2, 3, 1, 34, 987, 13, 7859, 2, 28, 1583, 12],
#  [2, 3, 1, 126, 69, 4584, 1648, 10, 4584, 3237],
#  [3, 75, 27, 6110, 769, 2934, 1298, 21650, 611],
#  [9, 11, 688, 2639, 587, 78, 6, 1, 2584],
#  [9, 11, 8, 33, 4, 110, 36, 29, 72273],
#  [15,
#   1060,
#   1623,
#   1344,
#   19,
#   3825,
#   173,
#   3422,
#   1316,
#   136,
#   786,
#   113,
#   135,
#   4,
#   809,
#   581],
#  [2, 3, 1, 162, 783, 21651, 42, 1124, 45],
#  [2, 946, 229, 10, 155, 683],
#  [16, 58, 25468, 114, 1766, 6, 138, 224, 10, 137],
#  [11, 224, 33407, 7, 3376, 8614, 10873, 65, 71, 1, 2694, 26],
#  [9, 942, 12, 39887],
#  [3,
#   17,
#   606,
#   13,
#   1036,
#   3987,
#   12256,
#   5,
#   3794,
#   218,
#   417,
#   19,
#   1198,
#   479,
#   99496,
#   32,
#   68,
#   7,
#   92,
#   24,
#   2125,
#   1512,
#   5,
#   2240],
#  [16, 31, 14, 534, 421, 4, 968, 2734, 27, 8394, 5, 12378],
#  [2, 12, 37326, 99497, 295, 1024, 36, 29, 1378],
#  [2, 12, 1, 1713, 7, 3946, 10, 22702, 151, 883, 1444],
#  [11, 688, 62, 3033, 32, 175, 170],
#  [9,
#   3,
#   17,
#   19,
#   8,
#   15,
#   33,
#   379,
#   5,
#   531,
#   631,
#   7,
#   651,
#   144,
#   18,
#   26284,
#   2431,
#   10,
#   129,
#   24,
#   2088,
#   3034,
#   5960,
#   13,
#   18,
#   475,
#   631,
#   7,
#   84],
#  [2, 3, 314, 4, 72274, 6, 4535],
#  [2, 12, 1, 108, 909, 13, 420, 6, 235, 3475, 413],
#  [2, 12, 1, 1279, 19, 25469, 8877, 24692, 58, 2025, 36, 4, 3253, 2210],
#  [2, 12, 38, 7, 1, 60, 3134, 1396, 6, 1, 94],
#  [61, 15, 56, 376, 13, 4371, 6, 99498, 861, 6785, 59865],
#  [2, 12, 3461, 1987, 6, 13580, 31921, 444, 6, 505],
#  [2, 3, 1, 480, 1442, 7, 1, 480, 7, 849, 37],
#  [2, 279, 5, 417, 40, 24, 309, 71, 3118, 6338],
#  [40, 3, 1, 622, 281, 313, 4511, 23, 123],
#  [8,
#   24,
#   10166,
#   111,
#   18,
#   256,
#   1702,
#   6,
#   630,
#   392,
#   11,
#   8,
#   24,
#   5,
#   316,
#   50,
#   6947,
#   1576],
#  [11, 14, 81, 45, 611, 360, 179, 375],
#  [2, 3, 1, 424, 988, 7, 2168, 397, 528, 6, 406, 163],
#  [2,
#   3,
#   1,
#   3243,
#   1965,
#   938,
#   19,
#   423,
#   5392,
#   97,
#   17293,
#   22,
#   356,
#   6,
#   4,
#   1046,
#   3232],
#  [16,
#   48,
#   3060,
#   47004,
#   149,
#   82,
#   52,
#   990,
#   8,
#   2596,
#   980,
#   19,
#   154,
#   49,
#   191,
#   5,
#   3057,
#   6467,
#   23,
#   4205,
#   1,
#   4994],
#  [2, 3, 887, 7, 1962],
#  [16, 39, 3, 2735, 7, 1199],
#  [3, 17, 1728, 2, 63, 2070, 179, 48, 5, 54, 118, 941],
#  [2, 11, 14, 67, 45, 1, 6139, 218, 25470, 12491],
#  [9, 48, 51, 1297, 19, 1, 356, 17033, 27, 861, 5, 950],
#  [9, 15, 8, 25, 4, 333, 8724],
#  [2, 3, 1, 19165, 69, 10227, 10, 11817, 259, 6, 3583, 4333],
#  [647, 14059, 7, 28, 1159, 905],
#  [2, 945, 31, 51, 331, 151, 1, 17844, 1517, 43, 138, 1385],
#  [9, 334, 3, 4219, 514, 5, 2115, 1054, 6, 489, 2902],
#  [61, 15, 8, 91, 4, 196, 6383, 6816, 8820, 5937],
#  [16,
#   11,
#   37,
#   22,
#   104,
#   44,
#   337,
#   18,
#   304,
#   45,
#   692,
#   430,
#   8,
#   96,
#   85,
#   5,
#   3070,
#   21,
#   37,
#   40,
#   385,
#   692,
#   430,
#   64,
#   105,
#   56,
#   530,
#   17],
#  [16, 11, 8, 234, 4279, 552, 82],
#  [32, 41, 1, 92, 173, 2818, 10792, 2257, 9571, 40, 12, 341, 1, 142, 36, 2264],
#  [2, 35214, 824, 2832, 88, 129, 1695, 6, 1, 9716],
#  [9, 11, 170, 2432, 1181, 10, 2201, 55, 1399, 6271],
#  [8,
#   24,
#   172,
#   1764,
#   13,
#   9849,
#   3293,
#   1576,
#   64,
#   4068,
#   502,
#   932,
#   10,
#   1604,
#   8527,
#   27,
#   18,
#   389,
#   258,
#   10,
#   1,
#   566,
#   3,
#   129,
#   1009,
#   13,
#   1764,
#   16,
#   52],
#  [612, 270, 9016, 1785, 6, 6448, 8168, 210, 2, 854, 10, 336, 15, 8, 711],
#  [58, 17, 93, 65, 606, 323, 3602, 5, 814, 4, 110, 195, 1, 9907, 864, 957, 443],
#  [2, 31, 115, 2039, 232, 538, 6, 39, 74],
#  [3, 1, 110, 340, 159, 13, 204, 6017, 6, 57, 868],
#  [35,
#   4,
#   597,
#   99,
#   22,
#   233,
#   328,
#   305,
#   4,
#   2177,
#   13,
#   194,
#   42,
#   128,
#   23,
#   5422,
#   1590],
#  [2, 12, 7718, 59866, 295, 1024, 36, 4, 2555],
#  [16,
#   11,
#   297,
#   120,
#   1,
#   574,
#   2736,
#   100,
#   85,
#   5,
#   121,
#   4,
#   568,
#   64,
#   1,
#   177,
#   626,
#   17,
#   3,
#   722,
#   13,
#   4,
#   1392,
#   10,
#   205,
#   10,
#   16,
#   12,
#   47,
#   52,
#   2045,
#   45,
#   1,
#   221],
#  [2, 3, 1, 1365, 13, 108, 103, 8477, 6, 30563],
#  [2, 12, 1, 34, 11214, 23, 3988, 6, 1, 94],
#  [2, 520, 48, 21652, 8615, 717, 36, 1, 2791, 707, 12862, 4890],
#  [41, 1010, 25, 129, 273, 6, 546, 113],
#  [3, 17, 201, 19, 1091, 3, 1031, 160, 7, 3603, 37],
#  [3, 17, 1131, 5, 24, 579, 6, 5759, 6, 1528],
#  [16, 35, 65, 37, 180, 6, 56, 137, 136, 268],
#  [3, 26285, 211, 579],
#  [5648, 1, 126, 69, 4, 24693, 10, 4, 13581],
#  [15, 8, 560, 454, 95, 710, 2543],
#  [15, 4, 1618, 331, 3469, 354, 6],
#  [2, 12, 38, 1677, 15427, 6, 511],
#  [2,
#   20,
#   8,
#   85,
#   5,
#   121,
#   881,
#   59,
#   5744,
#   6,
#   284,
#   231,
#   20,
#   44,
#   881,
#   2,
#   12,
#   73,
#   789,
#   482],
#  [2, 26, 1693, 67, 7, 728, 20342, 2111, 46, 308, 6, 55, 192],
#  [9, 48, 1843, 21653, 93, 5234],
#  [3, 39, 50, 8876, 13, 17, 3584, 6, 600],
#  [3, 17, 109, 5, 2318, 27, 735, 95, 1228, 17],
#  [9, 15, 8, 7323, 2140, 1440, 1125, 22703],
#  [41,
#   14,
#   25,
#   292,
#   5,
#   331,
#   4,
#   1729,
#   6849,
#   570,
#   69,
#   4,
#   6295,
#   15236,
#   10,
#   1,
#   6295,
#   1334],
#  [16, 3, 17, 290, 5, 690, 570, 27, 1, 331, 808],
#  [9, 11, 8, 33, 1180, 1272, 2892, 27, 406, 5, 1310],
#  [9, 15, 8, 1709, 139, 59867, 288, 3755],
#  [3, 39, 4, 6729, 3337, 5, 37, 27, 99499, 2664, 7526],
#  [11, 14, 67, 4048, 4709, 849, 7652],
#  [15, 14, 62, 65, 128, 36, 29, 15824],
#  [16, 115, 236, 24, 6658, 13, 193, 550],
#  [2, 12, 38, 395, 5, 250, 4, 3294, 45, 1143, 47, 892, 1, 72275, 164],
#  [40, 3, 1, 34, 5047, 13, 4, 108, 197, 1471, 2089, 6, 1060],
#  [1911, 1, 99500, 79, 5, 1847, 914, 1088, 5, 4, 179, 10874, 7, 1, 3510],
#  [2, 12, 28, 897, 22, 29338, 18444, 4928, 5, 99501],
#  [35, 1550, 1366, 14, 20, 14, 100, 24, 4, 1550, 258],
#  [9,
#   49,
#   99502,
#   210,
#   443,
#   46,
#   19579,
#   4696,
#   13,
#   828,
#   210,
#   7563,
#   9,
#   37,
#   12,
#   1515,
#   6211,
#   10,
#   11,
#   47,
#   5170,
#   111,
#   228,
#   189,
#   217,
#   23,
#   418,
#   298],
#  [8,
#   33,
#   1456,
#   246,
#   23,
#   3640,
#   6,
#   1,
#   267,
#   670,
#   13,
#   14203,
#   22,
#   3914,
#   66,
#   7,
#   18,
#   2235,
#   147,
#   21,
#   1304,
#   484,
#   14203,
#   3470,
#   8,
#   11,
#   44,
#   33,
#   72,
#   1381,
#   27,
#   19,
#   111,
#   176,
#   6501,
#   195,
#   1179,
#   2,
#   80,
#   8,
#   209,
# ...
#  [2,
#   3,
#   1,
#   396,
#   7,
#   535,
#   3686,
#   22,
#   13289,
#   11408,
#   10,
#   99509,
#   446,
#   3979,
#   59873,
#   590,
#   1760,
#   22,
#   390,
#   3979,
#   1074,
#   42,
#   4,
#   1571,
#   1904,
#   7,
#   2125,
#   590,
#   1075],
#  [2, 12, 38, 53, 395, 13, 47006],
#  [30, 498, 22183, 12, 1, 34, 5, 76, 32, 547, 937],
#  [16, 26, 104, 24, 4, 929, 1361],
#  [2, 3, 1, 1634, 79, 5, 33, 663, 7, 1949],
#  [9, 26, 1, 979, 1212, 5811, 615, 1, 427, 7, 1041],
#  [2, 481, 6, 1, 103, 513],
#  [9, 11, 12, 242, 99510, 4270, 1280, 19169, 119],
#  [9, 15, 8, 1950, 21, 18, 495, 83, 1543, 2105],
#  [4, 11913, 4165, 3, 4891, 28, 74, 14, 24, 1417, 631, 5, 2159, 2, 11, 14, 11],
#  [2, 26, 274, 116],
#  [11, 14, 24, 4, 1534, 283, 7, 354, 19, 14, 1685, 5, 32, 14, 12, 1655],
#  [15, 8, 149, 4, 6212, 5, 18, 2001, 9508, 13, 55, 5045],
#  [2, 12, 1, 528, 1486, 6, 2974, 163, 13, 29, 115, 181],
#  [2, 12, 38, 863, 22, 1, 521, 19, 12145, 8576, 2160],
#  [30, 315, 7, 208, 689, 649, 5, 4, 497, 405, 6, 802, 497, 575, 580],
#  [12, 1, 332, 271, 6213, 218, 1301, 478, 10, 6, 53, 2390],
#  [2, 11, 14, 67, 41, 188, 6, 5609, 185, 10, 379, 7, 1, 297],
#  [16, 11, 37, 67, 17, 3, 698, 5, 305, 37, 152, 564, 45, 444, 839],
#  [2,
#   12,
#   38,
#   1563,
#   19,
#   3947,
#   123,
#   3,
#   609,
#   5,
#   658,
#   1,
#   344,
#   277,
#   101,
#   29,
#   8395,
#   224],
#  [2, 12, 1, 6273, 7495, 45, 898],
#  [9, 3, 28, 204, 21, 16517, 937, 6, 57, 15, 47, 6787, 115, 6470, 1232],
#  [2, 12, 1, 7779, 5, 93, 29, 1928, 2410],
#  [3, 17, 2023, 5, 11, 3003, 21, 453, 6638, 6, 545, 148],
#  [11, 14, 36, 4, 935, 67, 19, 723, 31, 1130, 5, 1698, 6, 366, 5, 25, 3040],
#  [48, 15826, 33, 636],
#  [12, 39, 50, 2565, 45, 9, 235, 1201, 3, 3975, 73, 71, 6, 31923],
#  [40, 3, 1350, 13, 1, 2292, 265, 1514, 1, 6583],
#  [3, 2157, 3889, 523, 5, 1332, 4451, 16035],
#  [16, 12, 5925, 6639, 334, 22, 14876, 1066],
#  [9, 134, 26, 17, 86, 14, 5, 339, 4, 3511],
#  [9, 11, 12256, 93, 52, 1571],
#  [16,
#   12,
#   1693,
#   52,
#   11914,
#   13,
#   262,
#   13583,
#   25,
#   1127,
#   837,
#   95,
#   92,
#   10,
#   160,
#   51,
#   1311,
#   55,
#   489,
#   2603,
#   47,
#   15,
#   886,
#   65,
#   22,
#   233,
#   2024,
#   1330],
#  [61, 11, 8, 91, 1, 215, 16036, 43, 2213],
#  [3, 39, 4, 252, 13, 92],
#  [30,
#   446,
#   6,
#   57,
#   58,
#   4,
#   53,
#   5580,
#   13,
#   1704,
#   27200,
#   197,
#   704,
#   10,
#   197,
#   1180,
#   13,
#   16518],
#  [3,
#   17,
#   386,
#   5,
#   184,
#   6,
#   464,
#   6,
#   2914,
#   157,
#   544,
#   42,
#   19934,
#   14520,
#   17034,
#   19580],
#  [2, 3, 1, 5009, 3130, 13, 334, 715, 23, 47007, 1729, 23, 59874, 715],
#  [11, 287, 42, 2513, 5860, 3140, 149, 480, 151, 55, 547, 605],
#  [2, 4311, 84, 13, 1505, 5155],
#  [31,
#   51,
#   25,
#   65,
#   2716,
#   21,
#   1146,
#   9384,
#   1039,
#   3,
#   4,
#   860,
#   4166,
#   10,
#   16,
#   49,
#   77,
#   255,
#   13,
#   1,
#   123,
#   2180],
#  [3, 39, 50, 984, 13, 1168, 198, 99, 5, 4493, 5, 524, 27, 333, 1739],
#  [11,
#   6018,
#   590,
#   1539,
#   50,
#   243,
#   32,
#   47,
#   834,
#   4,
#   20749,
#   2358,
#   95,
#   23365,
#   7,
#   50,
#   17566,
#   23,
#   39888],
#  [11, 1067, 1010, 24, 8728],
#  [9, 11, 8, 180, 22, 578, 833, 4, 103],
#  [2, 3, 29, 27201, 322],
#  [9,
#   15,
#   8,
#   697,
#   18,
#   498,
#   27,
#   176,
#   3641,
#   32,
#   17,
#   13144,
#   20,
#   8,
#   206,
#   806,
#   112,
#   5,
#   207,
#   880,
#   10,
#   39,
#   3,
#   105,
#   1856,
#   591,
#   482,
#   13,
#   112,
#   5,
#   459,
#   247],
#  [2, 3, 1, 34, 79, 5, 378, 21, 170, 5875],
#  [7564, 8729, 3512],
#  [61, 12, 1, 34, 544, 10, 16, 377, 1007, 196, 4169, 110, 974],
#  [2, 3, 1, 510, 7, 1, 99511, 52204],
#  [9,
#   11,
#   8,
#   559,
#   412,
#   8,
#   120,
#   2735,
#   7,
#   128,
#   52,
#   8,
#   2376,
#   5,
#   559,
#   412,
#   50,
#   56,
#   4670,
#   182],
#  [61, 12, 1, 122, 211, 1283, 7, 4022, 140],
#  [1,
#   1233,
#   212,
#   3,
#   44,
#   4,
#   2449,
#   2218,
#   3433,
#   6,
#   1,
#   639,
#   52,
#   12,
#   51,
#   4892,
#   50,
#   70,
#   10305,
#   683,
#   514,
#   5,
#   155,
#   1603],
#  [35,
#   3223,
#   19935,
#   14204,
#   21,
#   16271,
#   4334,
#   8167,
#   10167,
#   62,
#   4,
#   53,
#   31924,
#   5393],
#  [2, 12, 38, 1549, 52205, 10629, 662, 13, 2623],
#  [2, 1, 99512, 69, 228, 1973, 10, 228, 72280],
#  [2, 88, 1, 60, 216, 185, 384, 7, 1, 333, 735],
#  [12, 14, 3358, 46, 956, 20, 14, 533, 22, 4, 9113, 14361],
#  [9, 48, 9851, 4296, 3685],
#  [2, 73, 284, 766, 789, 21, 309, 1364, 12, 39, 6, 57, 1715, 197, 1471],
#  [2, 72281, 12, 14, 3124, 5, 1038, 10, 35, 205, 4, 3497, 25, 386, 7858],
#  [16, 206, 37, 166, 1163, 1632, 1, 79, 688, 15],
#  [16,
#   11,
#   18,
#   2574,
#   8774,
#   230,
#   14062,
#   118,
#   22,
#   4,
#   2359,
#   10,
#   66,
#   18,
#   2574,
#   6019,
#   12,
#   6,
#   1,
#   47008,
#   1134,
#   1,
#   387,
#   237,
#   52,
#   487,
#   8,
#   560,
#   1613,
#   5,
#   18,
#   2574,
#   6019,
#   10,
#   24,
#   5,
#   3709,
#   66,
#   1,
#   8774,
#   8,
#   1099,
#   390,
#   1881,
#   6019,
#   237,
#   153],
#  [2, 11, 8, 120, 5, 11, 5, 93, 4, 333, 951, 405],
#  [15, 2119, 365, 8730, 3968],
#  [12, 39, 50, 563, 7, 3630, 7860, 16519],
#  [16,
#   11,
#   8,
#   67,
#   263,
#   53,
#   13,
#   4,
#   137,
#   5,
#   24,
#   65,
#   9910,
#   8080,
#   10,
#   259,
#   8080,
#   1072,
#   235,
#   825,
#   1461,
#   1037],
#  [9,
#   15,
#   8,
#   10048,
#   56,
#   7,
#   18,
#   37331,
#   3387,
#   45,
#   1,
#   843,
#   19,
#   90,
#   258,
#   3,
#   2606,
#   3865,
#   323,
#   17,
#   1188,
#   16272,
#   923,
#   3,
#   17,
#   109,
#   5,
#   749,
#   29,
#   2660,
#   1274],
#  [351, 28, 768, 472, 3295, 5111, 9, 35, 14, 426, 171, 112],
#  [16,
#   3228,
#   370,
#   173,
#   5367,
#   587,
#   21,
#   72,
#   1031,
#   192,
#   10,
#   121,
#   255,
#   22,
#   889,
#   587,
#   326],
#  [69, 99513, 99514, 10, 99515, 40, 49, 1, 34, 4358, 450],
#  [2, 11, 2244, 67, 45, 1, 857, 4575, 1603],
#  [9, 11, 14, 81, 20, 4, 269, 3, 96, 3926, 10, 4738, 23, 58, 1088, 13, 14],
#  [24, 14, 89, 2917, 22, 2093, 320, 6, 131],
#  [30, 287, 6, 57, 1366, 3348, 2164],
#  [2, 49, 1, 60, 1026, 14, 24, 89, 125, 6, 28, 74],
#  [2, 591, 3, 314, 5, 25, 785, 512],
#  [2, 3, 1, 34, 739, 13, 1149, 76, 10, 38, 423, 1730],
#  [40, 12, 1720, 1, 693, 579, 1518, 23, 1, 193, 579, 1518],
#  [2, 3, 1, 1525, 7, 21656, 6, 1217, 2511],
#  [30, 591, 6, 5510, 3, 4099, 13, 255, 124],
#  [2, 3, 1, 431, 7, 33412, 6, 4671],
#  [2, 3, 1, 60, 197, 187, 23, 437],
#  [117, 28, 1266, 732, 469, 19, 1955],
#  [2, 3, 1, 1660, 69, 1, 5532, 7, 356, 10, 1465, 35215],
#  [2, 3, 1, 126, 69, 1468, 2866, 10, 1, 4136, 3856],
#  [9, 3, 4335, 10168, 633, 43, 1493, 21169, 884],
#  [9, 11, 8, 230, 18, 43002, 438],
#  [30, 59875, 15, 504, 235, 6, 553, 99516],
#  [9, 134, 26, 4, 1101, 82, 1842, 86, 6, 1810],
#  [16,
#   3,
#   18,
#   1497,
#   13732,
#   6273,
#   22,
#   54,
#   71,
#   32,
#   616,
#   5,
#   18,
#   3937,
#   8,
#   80,
#   4,
#   122,
#   824],
#  [12, 66, 728, 3976, 1066, 99517],
#  [15, 51, 24, 4968, 1533, 6214, 22, 4, 3133, 1533, 3433],
#  [9, 11, 8, 349, 136, 4, 636, 227],
#  [2,
#   11,
#   14,
#   67,
#   7,
#   458,
#   1103,
#   108,
#   39889,
#   35216,
#   443,
#   9718,
#   46,
#   90,
#   1129,
#   6,
#   342],
#  [9, 49, 4181, 29, 2915, 13, 124, 6, 996, 2521],
#  [2, 3, 1, 1599, 224, 6, 604, 7, 813],
#  [2, 11, 619, 67, 1, 4644, 3, 16, 11, 47, 4117, 1, 4644, 10, 98, 47, 12, 1393],
#  [9, 11, 3162, 165, 199, 6, 3588, 4232],
#  [2, 3, 1, 34, 566, 5, 139, 798, 228],
#  [2, 3, 1, 1234, 7, 1, 7947, 1638, 72282, 602],
#  [12,
#   39,
#   537,
#   1969,
#   40,
#   24,
#   678,
#   55,
#   7713,
#   1371,
#   901,
#   23,
#   7861,
#   27,
#   311,
#   6,
#   262,
#   13,
#   52,
#   134],
#  [2,
#   35,
#   17,
#   86,
#   13,
#   92,
#   17035,
#   5,
#   1788,
#   2377,
#   1233,
#   5435,
#   22,
#   55,
#   21170,
#   9114,
#   23366],
#  [9,
#   35,
#   8,
#   25,
#   292,
#   5,
#   1539,
#   10630,
#   7,
#   352,
#   1073,
#   10,
#   2743,
#   87,
#   22,
#   473,
#   2,
#   1662,
#   3,
#   34,
#   5,
#   76,
#   10,
#   26,
#   174,
#   81,
#   9,
#   8,
#   97,
#   11,
#   17],
#  [9, 15, 8, 627, 4, 13733, 3749, 59, 7496, 1189, 862],
#  [11, 60, 705, 103, 6162, 24, 159, 25473, 10, 13290],
#  [6245,
#   946,
#   10169,
#   12,
#   53,
#   13,
#   28,
#   623,
#   10,
#   425,
#   9,
#   487,
#   31,
#   8,
#   86,
#   87,
#   654,
#   4,
#   153,
#   23,
#   2302,
#   4,
#   153],
#  [9, 730, 3, 325, 191, 6917],
#  [2, 3, 1, 1295, 732, 109, 13, 4, 99518],
#  [2, 15, 25, 5995, 1920, 1, 11593, 7, 1, 28281],
#  [2,
#   11,
#   14,
#   67,
#   7,
#   1,
#   546,
#   5336,
#   19581,
#   6850,
#   46,
#   59876,
#   10,
#   72283,
#   12,
#   39,
#   50,
#   295,
#   5706,
#   6,
#   63,
#   184],
#  [11, 14, 133, 67, 14, 97, 644, 195, 21, 421, 4, 1388, 3400, 13, 75],
#  [20, 14, 12493, 746, 1, 7390, 1396, 22, 63, 6976, 2, 35, 14, 1364, 22707],
#  [20,
#   4,
#   14362,
#   3841,
#   7607,
#   4,
#   235,
#   10,
#   19,
#   235,
#   3,
#   1902,
#   10,
#   19,
#   9444,
#   15,
#   1498,
#   19,
#   235,
#   64,
#   298,
#   2258,
#   17,
#   9,
#   35,
#   14,
#   106,
#   46,
#   24695,
#   19,
#   353,
#   988],
#  [16, 3, 17, 216, 5, 23990, 4, 2812, 144, 2834, 17, 5, 1, 11308],
#  [2, 15, 51, 11, 13, 138, 500],
#  [16, 12, 1, 43003, 722, 43, 50, 12863, 4333],
#  [26, 1, 5354, 7, 4, 5898, 374, 1, 8436],
#  [117, 1, 126, 69, 10876, 10, 5095, 11818],
#  [20, 8, 1436, 18, 104, 258, 15, 8, 76, 1, 142, 840, 1175, 5, 319, 268, 56],
#  [3, 39, 29, 8204, 79, 5, 461, 9, 99519, 5643, 3, 637],
#  [3, 394, 898, 4, 441, 137, 5, 657],
#  [2, 3, 1, 34, 3555, 27, 5511, 5, 1609, 2802, 20, 8, 24, 56, 700],
#  [2, 3, 1, 874, 7, 193, 579, 59877],
#  [16, 206, 51, 173, 942, 13895, 6, 57],
#  [8, 42, 5, 121, 4, 141, 23, 1100, 18, 12257, 141, 31, 8, 11, 2260, 23, 21171],
#  [2, 3, 1, 1576, 13, 3938, 1128, 178],
#  [2, 3, 1, 34, 2523, 709, 89, 1681],
#  [18, 623, 3542, 869, 21, 50, 293, 11110, 19, 8, 76, 16],
#  [16,
#   26,
#   18,
#   638,
#   360,
#   54,
#   112,
#   472,
#   32,
#   88,
#   912,
#   64,
#   32,
#   51,
#   12,
#   273,
#   18,
#   73,
#   3937,
#   154,
#   626,
#   154,
#   58,
#   105,
#   16765],
#  [2,
#   3,
#   1,
#   34,
#   79,
#   5,
#   6183,
#   1,
#   1008,
#   61,
#   8,
#   80,
#   2688,
#   72,
#   65,
#   71,
#   18,
#   251,
#   10,
#   47,
#   199,
#   43,
#   54,
#   21,
#   72284],
#  [26, 99520, 106, 3174, 6, 99521],
#  [5436, 9, 572, 35, 4, 4141, 2763, 11492, 25, 43, 1327, 3150, 25474],
#  [12,
#   1,
#   72285,
#   17036,
#   7,
#   1,
#   3882,
#   99522,
#   99523,
#   72286,
#   72287,
#   72288,
#   314,
#   12258,
#   23,
#   17036],
#  [31, 8, 182, 1490, 23, 4, 259],
#  [30, 221, 353, 145, 15, 33, 21, 11409, 348, 6, 630, 178, 1313, 1221],
#  [2,
#   12,
#   1,
#   2345,
#   19,
#   207,
#   27,
#   4,
#   597,
#   6608,
#   10,
#   55,
#   923,
#   3,
#   5,
#   1102,
#   14683,
#   146,
#   10,
#   1,
#   364,
#   673,
#   23,
#   364,
#   2215,
#   3,
#   386,
#   257],
#  [2, 35, 14, 11, 20, 14, 125, 1222, 23991, 136, 66, 311, 5926, 13, 56, 153],
#  [9, 11, 8, 2701, 1, 34, 3141, 881, 416, 2112, 13, 10170],
#  [40, 12, 1, 34, 3651, 43, 1, 163, 7, 4271],
#  [30, 3, 34, 16762, 8577, 23, 1723, 919, 13, 661],
#  [2, 12, 38, 216, 4004, 13, 630, 210, 13, 1450],
#  [11, 51, 33, 596, 7748, 6, 402, 2086],
#  [20,
#   1739,
#   47009,
#   1967,
#   800,
#   140,
#   35,
#   1,
#   414,
#   7,
#   1,
#   6111,
#   106,
#   82,
#   20,
#   944,
#   46,
#   9,
#   72],
#  [18, 893, 2348, 1748, 43004, 2052, 8, 658, 22, 1, 2348, 9, 15, 8, 976, 17],
#  [30, 462, 7, 84, 26, 57, 24, 1, 768, 1203],
#  [2, 1148, 7, 28, 110, 12, 1026],
#  [9, 26, 4, 141, 295, 181, 8034, 29, 452, 5046, 5, 90, 112, 1665, 439],
#  [9,
#   302,
#   35,
#   24,
#   35217,
#   99524,
#   254,
#   6,
#   4142,
#   20,
#   77,
#   502,
#   24,
#   90,
#   241,
#   3959,
#   46,
#   478,
#   839],
#  [15,
#   1614,
#   2482,
#   54,
#   45,
#   4483,
#   29,
#   1641,
#   1533,
#   13,
#   240,
#   2,
#   12,
#   38,
#   53,
#   2211,
#   6,
#   1,
#   1442,
#   7,
#   2104,
#   8437,
#   5,
#   14363,
#   21,
#   1202],
#  [16, 11, 37, 91, 4049, 6, 33413],
#  [30, 998, 31, 8, 182],
#  [2, 88, 450, 8663, 72289, 19582, 16766, 295, 1024],
#  [3, 4995, 441, 17845, 5048],
#  [2, 12, 38, 53, 329, 7, 6851, 6, 827],
#  [9, 2391, 3, 1, 274, 12034, 141, 484, 1289],
#  [2, 12, 1, 34, 1394, 13, 2138, 5876, 448, 641, 19, 12, 990, 99525],
#  [2, 3, 1, 643, 936, 7, 4143, 5188, 37],
#  [15, 51, 419, 793, 59, 7391, 6, 3857, 96, 5, 6640, 138, 4050],
#  [30, 4220, 323, 6062, 58, 2473, 1, 60, 2179],
#  [16, 11, 37, 6, 7254, 400, 4, 1381, 9976, 355, 5, 55, 10306, 274],
#  [2, 3, 1, 204, 7, 29, 115, 202, 191, 5, 57, 13, 353, 131],
#  [26, 17, 62, 984, 13, 4, 5305, 5125, 5, 10631, 2022, 4256, 3188],
#  [16, 26, 37332, 1275, 42, 4, 179],
#  [2, 287, 559, 242, 7009, 169, 641, 890, 4467, 1490],
#  [40, 3, 1, 733, 439, 1572, 7, 1779],
#  [6,
#   905,
#   7,
#   371,
#   1183,
#   489,
#   17846,
#   47,
#   3035,
#   21,
#   2,
#   4233,
#   5,
#   25,
#   4,
#   219,
#   12616,
#   16520,
#   1343,
#   3,
#   63,
#   55,
#   318,
#   12864,
#   1343],
#  [40, 12, 487, 10716, 5, 2678, 55, 8578],
#  [9, 1427, 59, 2586, 49, 4, 177, 2090, 455, 522, 3187, 6, 524],
#  [18, 2196, 3593, 1132, 22, 90, 84, 228, 9, 15, 8, 33, 171, 5, 173],
#  [2, 3, 1653, 59878, 6, 83, 4, 872],
#  [9, 2268, 11, 28, 266, 24, 5, 25, 13, 14, 5, 93, 379, 1562],
#  [2,
#   1051,
#   8,
#   31,
#   25,
#   421,
#   20,
#   8,
#   80,
#   175,
#   29,
#   437,
#   45,
#   4,
#   549,
#   19,
#   15,
#   882,
#   1,
#   433,
#   19,
#   37333,
#   399],
#  [2,
#   12,
#   1,
#   60,
#   572,
#   1895,
#   19,
#   2040,
#   12,
#   161,
#   5,
#   1164,
#   78,
#   5,
#   2134,
#   3693,
#   73,
#   71,
#   781,
#   1935,
#   10,
#   3452],
#  [20, 1, 5220, 133, 2406, 2, 3, 868, 255, 22],
#  [16, 26, 18, 4793, 360, 6296, 99526],
#  [16, 11, 8, 24, 3302, 12146, 787, 45, 83, 6, 555],
#  [2, 12, 38, 53, 10, 1549, 15429, 14684, 4085],
#  [3, 7608, 13009, 4, 53, 520, 673, 22, 265, 269],
#  [3151,
#   324,
#   7,
#   18,
#   2245,
#   2291,
#   176,
#   219,
#   5286,
#   13,
#   105,
#   7461,
#   381,
#   10,
#   1174,
#   39,
#   41,
#   25,
#   29,
#   5666,
#   14521,
#   5707,
#   23,
#   4,
#   1296,
#   6553,
#   42,
#   1686,
#   26,
#   174,
#   81,
#   2,
#   384,
#   63],
#  [2, 3, 126, 69, 4, 4524, 10, 4, 23367],
#  [2,
#   12,
#   1,
#   810,
#   7,
#   399,
#   687,
#   30,
#   399,
#   687,
#   3,
#   53,
#   13,
#   1856,
#   623,
#   8,
#   24,
#   1543,
#   1856,
#   623],
#  [2, 12, 1282, 7, 1690, 2607],
#  [2, 12, 38, 333, 640, 930, 5, 14, 5, 410, 3280],
#  [2, 4049, 3, 39, 6, 2337, 5221, 36, 3712],
#  [15, 14, 33, 1902, 27, 135, 213],
#  [58, 17, 89, 481, 19, 14, 678, 28, 2390, 10, 3107, 6, 322],
#  [9,
#   11,
#   8,
#   91,
#   78,
#   1,
#   1830,
#   13,
#   18,
#   4111,
#   11819,
#   1767,
#   3096,
#   409,
#   20,
#   8,
#   6384,
#   601,
#   56,
#   82],
#  [2, 12, 18, 740, 43, 47010, 5272, 224, 336, 6, 630],
#  [2, 12, 28, 1370, 144, 10, 59, 3969],
#  [323, 6880, 10, 2364, 12, 1, 9283, 7, 15237, 10, 47011, 12, 47, 3359],
#  [15, 8, 11, 2461, 148, 59, 209, 719, 148],
#  [16,
#   3,
#   17,
#   19,
#   1,
#   2519,
#   4948,
#   977,
#   7,
#   52206,
#   296,
#   984,
#   64,
#   4948,
#   1695,
#   7,
#   30565,
#   248],
#  [2, 12, 1, 110, 974, 59, 209, 2845, 1028],
#  [30, 1040, 125, 1, 1166, 1242, 6, 1160, 5017, 210],
#  [2, 3, 194, 19, 232, 1170, 5, 25, 488],
#  [2, 3, 282, 21, 1126, 6, 3491],
#  [19170, 39, 25, 65, 124, 6, 3567],
#  [97,
#   1,
#   313,
#   1030,
#   29,
#   2575,
#   366,
#   5380,
#   1,
#   4644,
#   27,
#   359,
#   2180,
#   4005,
#   43,
#   50,
#   422],
#  [61, 15, 8, 91, 6084, 640, 6, 99527, 1836],
#  [9, 26, 8205, 1367, 40, 8, 80, 59, 7220, 10, 30566, 55, 261],
#  [35, 14, 533, 5, 939, 28, 1712, 56],
#  [48, 14, 46, 50, 720, 106, 5, 4, 5549, 131],
#  [9, 68, 31925, 185, 5235, 11, 57, 24],
#  [12, 12259, 5512, 7, 13734, 2643],
#  [2, 3, 1, 34, 446, 14, 24, 89, 4059, 6, 1389],
#  [2, 12, 1, 34, 37334, 13, 6246],
#  [41, 4327, 367, 497, 229, 106, 1137, 10, 20, 52, 9, 41, 17, 106],
#  [9, 15, 8, 426, 18, 169, 3556, 3218],
#  [2, 12, 1, 1577, 7, 99528],
#  [9, 72, 26, 17, 307, 5, 474, 4, 734, 2528, 1001, 1095, 6, 1213],
#  [2, 41, 188, 5, 895, 32, 288, 1302, 78, 13, 1189, 1345, 1, 94, 27, 4, 23992],
#  [12, 11493, 6, 3163, 11408, 12494, 27, 1, 535, 1361],
#  [9,
#   15,
#   8,
#   139,
#   359,
#   4,
#   173,
#   2239,
#   19936,
#   372,
#   42,
#   1,
#   372,
#   6,
#   1,
#   1116,
#   10,
#   26,
#   17,
#   86,
#   52,
#   72,
#   70,
#   5,
#   62,
#   56],
#  [362,
#   18,
#   238,
#   1142,
#   82,
#   5,
#   54,
#   43,
#   4118,
#   10,
#   488,
#   30567,
#   1528,
#   8,
#   669,
#   18,
#   605,
#   10,
#   8,
#   24,
#   99529,
#   8,
#   96,
#   1211,
#   99530,
#   8,
#   2995,
#   99531,
#   154,
#   488,
#   19,
#   17,
#   49,
#   1277,
#   19,
#   8,
#   49,
#   3371,
#   32,
#   154,
#   753,
#   54,
#   49,
#   18,
#   2161,
#   1,
#   652,
#   56,
#   5,
#   149],
#  [2, 12, 1, 1148, 7, 4, 4949],
#  [4,
#   108,
#   249,
#   846,
#   25475,
#   5,
#   76,
#   22708,
#   13,
#   4,
#   6215,
#   588,
#   61,
#   105,
#   2164,
#   6,
#   1,
#   167,
#   24,
#   204,
#   6,
#   12617,
#   10,
#   22708,
#   36,
#   1,
#   12865,
#   2,
#   31,
#   8,
#   11],
#  [788, 3, 2589, 13, 54, 80, 8, 1, 111, 56],
#  [9, 49, 883, 1698, 7684, 99532, 71, 362],
#  [16, 3, 18, 1467, 37335, 10, 39890],
#  [2, 35, 24, 481, 20, 115, 11820, 125, 6584, 756],
#  [9,
#   11,
#   8,
#   62,
#   4,
#   503,
#   6,
#   600,
#   8,
#   84,
#   6,
#   17,
#   24,
#   3281,
#   128,
#   10,
#   8,
#   80,
#   53,
#   501,
#   10,
#   105,
#   236,
#   43,
#   4170],
#  [2, 12, 1, 584, 493, 7, 958, 5, 5410, 73, 71, 571, 4228],
#  [3,
#   39,
#   50,
#   4165,
#   1942,
#   6,
#   919,
#   30,
#   2526,
#   5,
#   1249,
#   13,
#   1,
#   8731,
#   2348,
#   59879,
#   99533,
#   2172],
#  [16, 245, 37, 12, 234, 44, 5059, 6, 66, 192],
#  [16, 11, 6450, 199, 2398, 27, 1, 1649],
#  [3, 17037, 4, 227, 23, 4, 321],
#  [40, 41, 349, 6, 372, 363, 1478, 3604, 911, 31926, 676, 2293, 99534],
#  ...]

# %%
# text_lens=[]
# for title in docs:
#     text_lens.append(len(word_tokenize(title)))

# %%
# max(text_lens)
# Out:
# 412

# %%
# np.quantile(text_lens,0.85)
# Out:
# 21.0

# %%
# pad documents to a max length of 4 words
max_length = 20
padded_docs = pad_sequences(encoded_docs, maxlen=max_length, padding='post')
print(len(padded_docs))
# Out:
# 1306122

# %%
padded_docs.shape
# Out:
# (1306122, 20)

# %%
rus = RandomUnderSampler(random_state=42)
padded_docs_rus,labels_rus = rus.fit_resample(padded_docs,labels)

# %%
padded_docs_rus.shape,labels_rus.shape,padded_docs.shape,labels.shape
# Out:
# ((161620, 20), (161620,), (1306122, 20), (1306122,))

# %%
np.unique(labels_rus,return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([80810, 80810], dtype=int64))

# %% [markdown]
# ### 3. Import embeddings
# The clever part: import a dictionary of word embeddings that translates each word into a 100 dimensional vector.

# %%
# load the whole embedding into memory
EMBEDDING_FILE = r"C:\Users\syed.nusrath\Downloads\DATA\glove.840B.300d.txt"
EMBEDDING_DIM = 100

def get_embedding():
    embeddings_index = {}
    f = open(EMBEDDING_FILE,'r', errors = 'ignore', encoding='utf-8')
    for line in f:
        values = line.split()
        word = values[0]
        try:
            coefs = np.asarray(values[1:], dtype="float32")
            embeddings_index[word] = coefs
        except:
            pass
            
    f.close()
    return embeddings_index

embeddings_index = get_embedding()

# %%
# create a weight matrix for words in training docs

def create_embedding_weights(vocab_size,t):
    embedding_matrix = np.zeros((vocab_size, 300))
    for word, i in t.word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
    print(embedding_matrix.shape)
    return embedding_matrix

# %%
embedding_matrix = create_embedding_weights(vocab_size,t)
# Out:
# (222162, 300)

# %% [markdown]
# ### 4. Network architecture

# %% [markdown]
# ##### Simple model

# %%
# define the model
model = Sequential()
model.add(Embedding(vocab_size, 300, weights=[embedding_matrix], input_length=20, trainable=False))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
# compile the model
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
# summarize the model
print(model.summary())

# %% [markdown]
# ##### LSTM model

# %%
## create model
model_glove = Sequential()
model_glove.add(Embedding(vocab_size, 300, input_length=20, weights=[embedding_matrix], trainable=False))
model_glove.add(Dropout(0.2))
model_glove.add(Conv1D(64, 5, activation='relu'))
model_glove.add(MaxPooling1D(pool_size=4))
model_glove.add(LSTM(100))
model_glove.add(Dense(1, activation='sigmoid'))
model_glove.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model_glove.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 20, 300)           66648600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 300)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 16, 64)            96064
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 4, 64)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               66000
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 66,810,765
# Trainable params: 162,165
# Non-trainable params: 66,648,600
# _________________________________________________________________

# %% [markdown]
# ### 5. Training and Evaluation
# Is it any good? Let's find out.
# Divide our dataset using a holdout strategy:

# %%
# split dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(padded_docs_rus, labels_rus, test_size=0.2, random_state=42)

# %%
# fit the model
model_glove.fit(X_train, y_train, epochs=5, verbose=0)

# %%
# evaluate the model
loss, accuracy = model_glove.evaluate(X_test, y_test, verbose=0)
print('Accuracy: %f' % (accuracy*100))
# Out:
# Accuracy: 88.754486

# %%
model_glove.predict(X_test)
# Out:
# array([[0.85577065],
#        [0.9414769 ],
#        [0.01048732],
#        ...,
#        [0.2845876 ],
#        [0.8001421 ],
#        [0.98263633]], dtype=float32)

# %%
ques = ['Has the United States become the largest dictatorship in the world?','How should I prepare for IIT K/IIM C/ ISI K PGDBA course exam and interview?']

# %%
t.fit_on_texts(ques)
# integer encode the documents
encoded_ques = t.texts_to_sequences(ques)
max_length = 20
padded_ques = pad_sequences(encoded_ques, maxlen=max_length, padding='post')
print(len(padded_ques))
# Out:
# 2

# %%
model_glove.predict(padded_ques)
# Out:
# array([[0.7563303 ],
#        [0.00217064]], dtype=float32)
